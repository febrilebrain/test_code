# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import math
import random
import bisect
import copy
from scipy.spatial import Voronoi, voronoi_plot_2d
from itertools import accumulate
import networkx as nx
from randomScatter import RandomScatter
from direction import Direction
from vertex import VertexBase, VertexOrigin, VertexLayer

import ast

random.seed(0)
np.random.seed(0)

"""
We randomly give each center v a population p_v in the population_range.
If w is a node with unit distance d to v, its population is increased
by p_v / 2^d, for d <= 2 (parameters can be adjusted at the top).
The demand on any o-d-pair (o, d) is then given by p_o * p_d.
"""

if __name__ =="__main__":

    ERROR_MESSAGE = '----------------------'
    IMAGE_INPUT_PATH = './image_input/scatter_rate.jpg'
    IMAGE_OUTPUT_PATH = './image_output/'
    ROADMAP_RECTANGLE = ['./image_input/roadMapRectangle_00.jpg']
    ROADMAP_CIRCLE = ['./image_input/roadMapCircle_00.jpg',
                        './image_input/roadMapCircle_01.jpg',
                        './image_input/roadMapCircle_02.jpg',
                        './image_input/roadMapCircle_03.jpg']

    if not os.path.exists(IMAGE_OUTPUT_PATH):
        os.mkdir(IMAGE_OUTPUT_PATH)

    randomScatterInstance = RandomScatter(IMAGE_INPUT_PATH, 100, 0, reverse=True, squared=True)
    randomScatterInstance.readImage()
    randomScatterInstance.randomDots()
    randomScatterInstance.makePoints()

    #run improvePoints twice to refine points' locations
    randomScatterInstance.improvePoints(randomScatterInstance.points)
    randomScatterInstance.improvePoints(randomScatterInstance.improvedPoints) * 1#_, graph = 

    directionInstance = Direction(ROADMAP_RECTANGLE, ROADMAP_CIRCLE)

    vertexLayertInstance = VertexLayer(randomScatterInstance, directionInstance)
    
#     figs = voronoi_plot_2d(vor)
    
#     plt.ion()
#     plt.ioff()
#     plt.show()
    fig = plt.figure(figsize=(10,10))
    ax = plt.gca()
    ax.set_xlim(left=0, right=randomScatterInstance.shape[1])
    ax.set_ylim(top=0, bottom=randomScatterInstance.shape[0])

    
    for i in range(10):
        vertexLayertInstance.getNextVertices()
        vertexLayertInstance.mergeNextVertices(5)
        vertexLayertInstance.mergeToAll(3)
        vertexLayertInstance.plotLines(vertexLayertInstance.verticesNext, True)
#         if len(vertexLayertInstance.verticesNext)<=3:
#             break
        vertexLayertInstance.changeNextVertices()

#     pos = nx.get_node_attributes(graph, 'pos')
#     nx.draw_networkx_nodes(graph, pos=pos, node_size=6, node_color='k')
#     nx.draw_networkx_edges(graph, pos=pos, width=2)

#     plt.axis('off')
#     plt.show()
#     print(vertexLayertInstance.verticesAll)   # What do the coordinates mean?

    # vertexLayertInstance.plotLines(vertexLayertInstance.verticesAll+vertexLayertInstance.verticesOrigin)

#     _cos = []
#     nbr = []
#     for node in vertexLayertInstance.verticesAll:
#         nbrs = []
#         if node.goesTo:
#             nbrs = [i[0] for i in node.goesTo]
#         if any(node.comesFrom):
#             nbrs.extend([i[0] for i in node.comesFrom])
#         if len(nbrs) >= 5:
#             stops.append(node)
#             nbr = nbrs
#         elif len(nbrs) < 5:
#             if random.uniform(0, 1) < 0.2:
#                 stops.append(node)
# #         print(len(nbrs))
#     vertexLayertInstance.plotVertices(stops, 0.2, '#0000ff')
#     vertexLayertInstance.plotVertices(nbr, 0.2, '#00ff00')

#     for ver in vertexLayertInstance.verticesOrigin:
#         ver.dem += 0.3
#     vertexLayertInstance.plotVertices(vertexLayertInstance.verticesOrigin, 0.2, '#0000ff')
#     for path in path_list:
#         x_coor = []
#         y_coor = []
#         for ver in path:
#             x_coor.append(ver.position[1])
#             y_coor.append(ver.position[0])
# #         print(x_coor, y_coor)
#         plt.plot(x_coor, y_coor, marker = "o")
    plt.savefig(IMAGE_OUTPUT_PATH+'output.png')
    plt.show()
# Out:
# [193, 0] a
# [0, 87] a
# [225.60869851590735, 120.62559169163762] a
# [-95.67896501175733, 254.95629967999784] a
# [326.7055681970122, 97.7299971234648] a
# [282.11058467741935, 62.02537103551098] a
# [145.91217936471932, 203.4631997545245] a
# [207.63437765634487, 177.10775349119612] a
# [165.072834625316, -13.458411134188784] a
# [137.6978053474731, -46.47998204806411] a
# No vertex was added!
# No vertex was added!
# [<vertex.VertexDescendant object at 0x000001C59387A248>, -0.0] aaaaaaaaaaaa
# No vertex was added!
# [<vertex.VertexDescendant object at 0x000001C595925EC8>, -0.0] aaaaaaaaaaaa
# [<vertex.VertexDescendant object at 0x000001C594DFE108>, -0.0] aaaaaaaaaaaa
# No vertex was added!

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import math
import random
import bisect
import copy
from scipy.spatial import Voronoi, voronoi_plot_2d
from itertools import accumulate
import networkx as nx
from randomScatter import RandomScatter
from direction import Direction
from vertex import VertexBase, VertexOrigin, VertexLayer

import ast

random.seed(0)
np.random.seed(0)

"""
We randomly give each center v a population p_v in the population_range.
If w is a node with unit distance d to v, its population is increased
by p_v / 2^d, for d <= 2 (parameters can be adjusted at the top).
The demand on any o-d-pair (o, d) is then given by p_o * p_d.
"""

if __name__ =="__main__":

    ERROR_MESSAGE = '----------------------'
    IMAGE_INPUT_PATH = './image_input/scatter_rate.jpg'
    IMAGE_OUTPUT_PATH = './image_output/'
    ROADMAP_RECTANGLE = ['./image_input/roadMapRectangle_00.jpg']
    ROADMAP_CIRCLE = ['./image_input/roadMapCircle_00.jpg',
                        './image_input/roadMapCircle_01.jpg',
                        './image_input/roadMapCircle_02.jpg',
                        './image_input/roadMapCircle_03.jpg']

    if not os.path.exists(IMAGE_OUTPUT_PATH):
        os.mkdir(IMAGE_OUTPUT_PATH)

    randomScatterInstance = RandomScatter(IMAGE_INPUT_PATH, 200, 0, reverse=True, squared=True)
    randomScatterInstance.readImage()
    randomScatterInstance.randomDots()
    randomScatterInstance.makePoints()

    #run improvePoints twice to refine points' locations
    randomScatterInstance.improvePoints(randomScatterInstance.points)
    randomScatterInstance.improvePoints(randomScatterInstance.improvedPoints) * 1#_, graph = 

    directionInstance = Direction(ROADMAP_RECTANGLE, ROADMAP_CIRCLE)

    vertexLayertInstance = VertexLayer(randomScatterInstance, directionInstance)
    
#     figs = voronoi_plot_2d(vor)
    
#     plt.ion()
#     plt.ioff()
#     plt.show()
    fig = plt.figure(figsize=(10,10))
    ax = plt.gca()
    ax.set_xlim(left=0, right=randomScatterInstance.shape[1])
    ax.set_ylim(top=0, bottom=randomScatterInstance.shape[0])

    
    for i in range(20):
        vertexLayertInstance.getNextVertices()
        vertexLayertInstance.mergeNextVertices(5)
        vertexLayertInstance.mergeToAll(3)
        vertexLayertInstance.plotLines(vertexLayertInstance.verticesNext, True)
        if len(vertexLayertInstance.verticesNext)<=3:
            break
        vertexLayertInstance.changeNextVertices()

#     pos = nx.get_node_attributes(graph, 'pos')
#     nx.draw_networkx_nodes(graph, pos=pos, node_size=6, node_color='k')
#     nx.draw_networkx_edges(graph, pos=pos, width=2)

#     plt.axis('off')
#     plt.show()
#     print(vertexLayertInstance.verticesAll)   # What do the coordinates mean?

    # vertexLayertInstance.plotLines(vertexLayertInstance.verticesAll+vertexLayertInstance.verticesOrigin)

#     stops = []
#     nbr = []
#     for node in vertexLayertInstance.verticesAll:
#         nbrs = []
#         if node.goesTo:
#             nbrs = [i[0] for i in node.goesTo]
#         if any(node.comesFrom):
#             nbrs.extend([i[0] for i in node.comesFrom])
#         if len(nbrs) >= 5:
#             stops.append(node)
#             nbr = nbrs
#         elif len(nbrs) < 5:
#             if random.uniform(0, 1) < 0.2:
#                 stops.append(node)
# #         print(len(nbrs))
#     vertexLayertInstance.plotVertices(stops, 0.2, '#0000ff')
#     vertexLayertInstance.plotVertices(nbr, 0.2, '#00ff00')

#     for ver in vertexLayertInstance.verticesOrigin:
#         ver.dem += 0.3
#     vertexLayertInstance.plotVertices(vertexLayertInstance.verticesOrigin, 0.2, '#0000ff')
#     for path in path_list:
#         x_coor = []
#         y_coor = []
#         for ver in path:
#             x_coor.append(ver.position[1])
#             y_coor.append(ver.position[0])
# #         print(x_coor, y_coor)
#         plt.plot(x_coor, y_coor, marker = "o")
    plt.savefig(IMAGE_OUTPUT_PATH+'output.png')
    plt.show()
# Out:
# [193, 0] a
# [0, 87] a
# [0, 103] a
# [135.8470436566714, -28.17927448389579] a
# [213.79378127830492, 49.672541858797906] a
# [204.09253111697896, 121.03250723535028] a
# [209.07956250942235, 94.6819283118559] a
# [122.91334597566428, -52.76256902448898] a
# [176.5661413053271, 208.43969461436592] a
# [218.272353289344, 173.47618065287497] a
# [159.4611468428354, -41.23946862466151] a
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# [<vertex.VertexDescendant object at 0x000001A65EE13F40>, -0.0] aaaaaaaaaaaa
# [<vertex.VertexDescendant object at 0x000001A65EE61DF0>, -0.0] aaaaaaaaaaaa
# No vertex was added!
# No vertex was added!
# No vertex was added!
# [<vertex.VertexDescendant object at 0x000001A65F8BDFA0>, -0.0] aaaaaaaaaaaa
# [<vertex.VertexDescendant object at 0x000001A65EEF67F0>, -0.0] aaaaaaaaaaaa
# No vertex was added!
# No vertex was added!
# [<vertex.VertexDescendant object at 0x000001A65EEC8040>, -0.0] aaaaaaaaaaaa
# [<vertex.VertexDescendant object at 0x000001A65EEC8040>, -0.0] aaaaaaaaaaaa
# No vertex was added!
# [<vertex.VertexDescendant object at 0x000001A65F293E50>, -0.0] aaaaaaaaaaaa
# No vertex was added!
# [<vertex.VertexDescendant object at 0x000001A65F7D4850>, -0.0] aaaaaaaaaaaa
# [<vertex.VertexDescendant object at 0x000001A660D5B5B0>, -0.0] aaaaaaaaaaaa

# %% [markdown]
# # See this cell

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import os
import cv2
import math
import random
import bisect
from scipy.spatial import Voronoi, voronoi_plot_2d
from itertools import accumulate, combinations

from copy import deepcopy
from randomScatter import RandomScatter
from direction import Direction
from vertex import VertexBase, VertexOrigin, VertexLayer


if __name__ =="__main__":

    ERROR_MESSAGE = '----------------------'
    IMAGE_INPUT_PATH = './image_input/scatter_rate.jpg'
    IMAGE_OUTPUT_PATH = './image_output/'
    ROADMAP_RECTANGLE = ['./image_input/roadMapRectangle_00.jpg']
    ROADMAP_CIRCLE = ['./image_input/roadMapCircle_00.jpg',
                        './image_input/roadMapCircle_01.jpg',
                        './image_input/roadMapCircle_02.jpg',
                        './image_input/roadMapCircle_03.jpg']
    
#     #shuffle for diff radial centres
#     random.shuffle(ROADMAP_CIRCLE)
    
    if not os.path.exists(IMAGE_OUTPUT_PATH):
        os.mkdir(IMAGE_OUTPUT_PATH)

    randomScatterInstance = RandomScatter(IMAGE_INPUT_PATH, 30, 0, reverse=True, squared=True)
    randomScatterInstance.readImage()
    randomScatterInstance.randomDots()
    randomScatterInstance.makePoints()

    #run improvePoints twice to refine points' locations
    randomScatterInstance.improvePoints(randomScatterInstance.points)
    _, graph, points = randomScatterInstance.improvePoints(randomScatterInstance.improvedPoints) * 1
    print(points[0], 'b')
    directionInstance = Direction(ROADMAP_RECTANGLE, ROADMAP_CIRCLE)

    vertexLayertInstance = VertexLayer(randomScatterInstance, directionInstance)
    
#     plt.show()
    fig = plt.figure(figsize=(10,10))
    ax = plt.gca()
    ax.set_xlim(left=0, right=randomScatterInstance.shape[1])
    ax.set_ylim(top=200, bottom=0)#randomScatterInstance.shape[0])
    plt.figure(1,figsize=(10,10)) 

#     pos = nx.get_node_attributes(graph, 'pos')
#     nx.draw_networkx_nodes(graph, pos=pos, node_size=6, node_color='k')
#     nx.draw_networkx_edges(graph, pos=pos, width=2)
    
    verts = []
    vertexlist={}
    vertexdem = {}
    c=0
    adjdict={}
    for i in range(20):
        vertexLayertInstance.getNextVertices()
        vertexLayertInstance.mergeNextVertices(5)
        vertexLayertInstance.mergeToAll(3)
        if len(vertexLayertInstance.verticesNext)<=3:
            vertexLayertInstance.changeNextVertices()
            break
        vertexLayertInstance.plotLines(vertexLayertInstance.verticesNext, True)
        for i in vertexLayertInstance.verticesNext:
            if tuple(i.position) not in vertexlist:
                vertexlist[tuple(i.position)] = i.index
                verts.append(i.index)
                vertexdem[tuple(i.position)] = i.dem
#                 c+=1
            
        for i in vertexLayertInstance.verticesNext:
            for j in i.comesFrom:
                if tuple(i.position) not in vertexlist:
                    vertexlist[tuple(i.position)] = i.index
                    verts.append(i.index)
                    vertexdem[tuple(i.position)] = i.dem
#                     c+=1

                if tuple(j[0].position) in vertexlist:
                    if vertexlist[tuple(j[0].position)] in adjdict:
                        adjdict[vertexlist[tuple(j[0].position)]].update({vertexlist[tuple(i.position)]:{'weight':j[0].getDistance(i)}})
                    else:
                        adjdict[vertexlist[tuple(j[0].position)]] = {vertexlist[tuple(i.position)]:{'weight':j[0].getDistance(i)}}
                else:
                    vertexlist[tuple(j[0].position)] = j[0].index
                    verts.append(j[0].index)
                    vertexdem[tuple(j[0].position)] = j[0].dem
#                     c+=1
                    if vertexlist[tuple(j[0].position)] in adjdict:
                        adjdict[vertexlist[tuple(j[0].position)]].update({vertexlist[tuple(i.position)]:{'weight':j[0].getDistance(i)}})
                    else:
                        adjdict[vertexlist[tuple(j[0].position)]] = {vertexlist[tuple(i.position)]:{'weight':j[0].getDistance(i)}}

            for j in i.goesTo:
                if tuple(j[0].position) not in vertexlist:
                    vertexlist[tuple(j[0].position)] = j[0].index
                    verts.append(j[0].index)
                    vertexdem[tuple(j[0].position)] = j[0].dem
#                     c+=1

                if tuple(i.position) in vertexlist:
                    if vertexlist[tuple(i.position)] in adjdict:
                        adjdict[vertexlist[tuple(i.position)]].update({vertexlist[tuple(j[0].position)]:{'weight':i.getDistance(j[0])}})
                    else:
                        adjdict[vertexlist[tuple(i.position)]] = {vertexlist[tuple(j[0].position)]:{'weight':i.getDistance(j[0])}}
                else:
                    vertexlist[tuple(i.position)] = i.index
                    verts.append(i.index)
                    vertexdem[tuple(i.position)] = i.dem
#                     c+=1
                    if vertexlist[tuple(i.position)] in adjdict:
                        adjdict[vertexlist[tuple(i.position)]].update({vertexlist[tuple(j[0].position)]:{'weight':i.getDistance(j[0])}})
                    else:
                        adjdict[vertexlist[tuple(i.position)]] = {vertexlist[tuple(j[0].position)]:{'weight':i.getDistance(j[0])}}

        vertexLayertInstance.changeNextVertices()
    
#     print(vertexLayertInstance)
    for i in vertexLayertInstance.verticesAll:
        if tuple(i.position) not in vertexlist:
            vertexlist[tuple(i.position)]=i.index
#             c+=1
#     print(len(vertexlist), len(vertexLayertInstance.verticesAll), vertexLayertInstance.verticesAll[-1].totalIndex)
    vertexlistinv = {v: k for k, v in vertexlist.items()}
    vertexLayertInstance.plotVertices(vertexLayertInstance.verticesOrigin, alpha = 1.0)

    x_coor = []
    y_coor = []
    for ver in points:
        x_coor.append(ver[0])
        y_coor.append(ver[1])
    plt.scatter(x_coor, y_coor, c='#00ff00', alpha = 1.0)
#     for ver in points:
#         plt.annotate(ver, ver)
vertexpos={}
for k,v in vertexlistinv.items():
#     pos=[float(x) for x in v.replace("[",'').replace("]",'').split()]
    pos=v
#     print(v)
    vertexpos[k] = pos[::-1]
# vertexpos={k:ast.literal_eval(v) for (k,v) in vertexlistinv}
G = nx.Graph(adjdict)
G.remove_edges_from(nx.selfloop_edges(G))
unneeded = []
for n in G.nodes:
    if len(list(G.neighbors(n))) == 1:
        nbrs = list(G.neighbors(n))
        if len(list(G.neighbors(nbrs[0]))) > 2:
            unneeded.append(n)
print(unneeded)
for i in range(len(unneeded)):
    G.remove_node(unneeded[i])
#     ax.set_xticks((0, 50, 100, 150, 200))
#     ax.set_yticks((0, 50, 100, 150, 200))
nx.draw(G, vertexpos, node_size=10, font_size=8)
plt.show()
# Out:
# [0, 48] a
# [16, 0] a
# [144, 0] a
# [-141.3756387708622, -26.389040378100464] a
# [204.96153846153848, 162.03846153846155] a
# [67.94888331507337, -34.85025570260404] a
# [92.76455209107979, -7.833371492566241] a
# [-141.3756387708622, -26.389040378100464] b
# [27767, 27711, 27829, 27728, 27744, 27884, 27749, 27769, 27807, 27827, 27844, 27972, 27856, 27958, 27971]

# %%
fig = plt.figure(figsize=(10,10))
nx.draw(G, vertexpos, node_size=10, font_size=8)
plt.show()

# %%
T = deepcopy(G)

combs = list(combinations(G.nodes(), 2))
nodes_to_remove = []
edges_to_add = []
for n1,n2 in combs:
#     print(vertexpos[n1], vertexpos[n2])
    if n1 in T.nodes() and n2 in T.nodes():
        temp = math.sqrt((vertexpos[n1][0] - vertexpos[n2][0]) ** 2.0 + (vertexpos[n1][1] - vertexpos[n2][1]) ** 2.0)
        if temp < 3:# and n1 not in T.neighbors(n2):
            for n in T.neighbors(n1):
                edges_to_add.append((n2, n))
            if n1 not in nodes_to_remove:
                nodes_to_remove.append(n1)

T.add_edges_from(edges_to_add)                
for node in nodes_to_remove:
    T.remove_node(node)
T.remove_edges_from(nx.selfloop_edges(T))
print(len(T.edges()))
fig = plt.figure(figsize=(15,15))
nx.draw(T, vertexpos, node_size=10, font_size=8)
plt.show()
# Out:
# 822

# %%
nw_points = []
for ver in T.nodes():
    if len(list(T.neighbors(ver))) >= 4:
        nw_points.append(ver)
# print(len(nw_points))
nw_pts = deepcopy(nw_points)
# for pt in nw_points:
#     if any(n in list(T.neighbors(pt)) for n in nw_points):
#         nw_pts.pop(nw_pts.index(pt))
# print(len(nw_pts))

plt.figure(1,figsize=(20,20)) 
x_co = []
y_co = []
for ver in nw_points:
    x_co.append(vertexpos[ver][0])
    y_co.append(vertexpos[ver][1])

# print(len(x_co), x_co, y_co)

plt.scatter(x_co, y_co, c='#0000ff', alpha = 1.0)

nx.draw(T, vertexpos, node_size=10, font_size=8)
# fig = plt.figure(figsize=(10,10))
# nx.draw(P, vertexpos, node_size=10, font_size=8)
# plt.show()

# %%
# T = deepcopy(G)

# combs = list(combinations(G.nodes(), 2))
# # print(adjdict)
# # for n in G.nodes():
# #     if n in adjdict.keys():
# #         print(vertexpos[n])
# #     break
# for n1,n2 in combs:
# #     print(vertexpos[n1], vertexpos[n2])
#     if n1 in T.nodes() and n2 in T.nodes():
#         temp = math.sqrt((vertexpos[n1][0] - vertexpos[n2][0]) ** 2.0 + (vertexpos[n1][1] - vertexpos[n2][1]) ** 2.0)
#         if temp < 3 and n1 not in T.neighbors(n2):
#             for n in T.neighbors(n1):
#                 T.add_edge(n2, n)
#             T.remove_node(n1)
# T.remove_edges_from(nx.selfloop_edges(T))
# print(len(T.edges()))
# fig = plt.figure(figsize=(10,10))
# nx.draw(T, vertexpos, node_size=10, font_size=8)
# plt.show()

# %%
# new_points = []
# for pt in points:
#     nearest = 500
#     best_pt = None
#     for ver in vertexpos.values():
# #         print(ver, pt)
#         temp = math.sqrt(sum((px - qx) ** 2.0 for px, qx in zip(ver, pt)))
#         if temp < nearest:
#             best_pt = ver
#             nearest = temp
#     new_points.append(best_pt)

# plt.figure(1,figsize=(10,10)) 
# x_co = []
# y_co = []
# for ver in new_points:
#     x_co.append(ver[0])
#     y_co.append(ver[1])

# print(len(x_co), x_co, y_co)

# plt.scatter(x_co, y_co, c='#00ff00', alpha = 1.0)

# nx.draw(G, vertexpos, node_size=10, font_size=8)

# %%
temps = []
for pt in points:
    nearest = 50000
    best_pt = None
#     for ver in vertexpos.values():
    for nd in T.nodes():
        ver = vertexpos[nd]
#         print(ver, pt)
        temp = math.sqrt(sum((px - qx) ** 2.0 for px, qx in zip(ver, pt)))

        key_v=vertexlist[ver[::-1]]
        if key_v in adjdict:
            deg=len(adjdict[key_v])
        else:
            deg=0.001
        vvv = (1/vertexdem[ver[::-1]])*(1/deg)*temp
# #         print(deg)
#         if deg != 0:
#             vvv = (1/vertexdem[ver[::-1]])*(1/deg)*temp
#         else:
#             vvv = 1000
#         print(vvv)
        if vvv < nearest:
            best_pt = ver
            nearest = vvv
            
    temps.append(best_pt)

for el in nw_points:
    temps.append(vertexpos[el])

print(len(temps))
new_points = []
for el in temps:
    if el not in new_points:
        new_points.append(el)
print(len(new_points))
plt.figure(1,figsize=(10,10)) 
x_co = []
y_co = []
for ver in new_points:
    x_co.append(ver[0])
    y_co.append(ver[1])

# print(len(x_co), x_co, y_co)

plt.scatter(x_co, y_co, c='#0000ff', alpha = 1.0)

nx.draw(T, vertexpos, node_size=10, font_size=8)
# Out:
# 126
# 114

# %%
# nw_points = []
# x_c = []
# y_c = []
# for ver in vertexLayertInstance.verticesOrigin:
#     temp = (tuple(ver.position))
#     x_c.append(temp[1])
#     y_c.append(temp[0])

# plt.figure(1,figsize=(10,10))

# plt.scatter(x_co, y_co, c='#ff0000', alpha = 1.0)
# # plt.scatter(x_c, y_c, c='#00ff00', alpha = 1.0)

# #     nw.points.append(temp[::-1])
# nx.draw(G, vertexpos, node_size=10, font_size=8)
print(len(new_points))
# Out:
# 114

# %%
vertexposinv={v:k for (k,v) in vertexpos.items()}
labels = []
for pt in new_points:
#     print(pt)
    labels.append(vertexposinv[pt])
# print(labels)
# print(len(new_points))

# %%
# plt.figure(1,figsize=(20,20))
fig, ax = plt.subplots(figsize=(20,20))
ax.scatter(x_co, y_co, c='#00ff00', alpha = 1.0)
for i, txt in enumerate(labels):
    ax.annotate(txt, (x_co[i], y_co[i]))
nx.draw(T, vertexpos, node_size=10, font_size=10)

# %%
# # for pt in new_points:
# #     print(pt[::-1] in list(vertexlist.keys()))
# idx = []
# # print(new_points)
# for pt in new_points:
# #     print(vertexposinv[pt])
#     print(list(H.neighbors(vertexposinv[pt])))
'''
all pairs of nodes, shortest paths
'''
# Out:
# '\nall pairs of nodes, shortest paths\n'

# %%
# # print(vertexpos)
# # for ver in new_points:
# #     print(vertexdem[ver[::-1]])
# for pt in new_points:
# #     print(vertexposinv[pt])
#     nbs = list(H.neighbors(vertexposinv[pt]))
#     print(nbs)
#     for nb in nbs:
#         print(nb)
#         idx = vertexpos[nb]
#         print(vertexdem[idx[::-1]])
#     break
# print(len(list(T.neighbors(494))))
# print(len(new_points))
'''
update vertexpos, vertexposinv, vertexdem
'''
# print(list(nx.all_shortest_paths(T,2320,2546)))
# Out:
# '\nupdate vertexpos, vertexposinv, vertexdem\n'

# %%
# from itertools import combinations
# from copy import deepcopy

# '''
# Keep sorted list of neighbors by distance
# If closest neighbor already in visited, go to next
# If all neighbors in visited, then break
# '''
# visited = []
# path_list = []
# for pt in new_points:
#     J = deepcopy(T)
# #     if pt not in visited:
#     visited.append(pt)
# #     print(pt)
#     print(vertexposinv[pt], 'starting point')
#     path = []    #[vertexposinv[pt]
#     nw_pts = deepcopy(new_points)
#     nw_pts.pop(nw_pts.index(pt))
#     while len(path) <= 50:
# #         if path != []:
# #             path.pop()
#         node = visited[-1]
#         print(vertexposinv[node], 'starting node')
# #         print([vertexposinv[el] for el in visited])
#         nearest = 5000
#         dists = []
#         breaker = 0
#         for ver in nw_pts:
#             temp = math.sqrt((node[0] - ver[0]) ** 2.0 + (node[1] - ver[1]) ** 2.0)
#             dists.append((ver,temp))
#         dists.sort(key=lambda tup: tup[1])
#         nbrs = [el[0] for el in dists]
# #         print(vertexposinv[nbrs[0]])
#         for el in nbrs:
#             if nx.has_path(J,vertexposinv[node],vertexposinv[el]):
#                 if el not in visited:
#                     if not nx.shortest_path(J,vertexposinv[node],vertexposinv[el]):
# #                         visited.append(el)
#                         print('a')#vertexposinv[node],vertexposinv[el])
#         #                 continue
#                     else:
#                         print(vertexposinv[el], 'neighbor')
#                         idxs = [vertexposinv[i] for i in visited]
#                         idxs.pop()
#                         temp_path = list(nx.shortest_path(J,vertexposinv[node],vertexposinv[el]))
#                         print(idxs,'visited')
#                         print(temp_path,'new path')
#                         if any(v in temp_path for v in idxs) == False:
#                             print('not common')
#                             if path != []:
#                                 path.pop()
#                             path.extend(nx.shortest_path(J,vertexposinv[node],vertexposinv[el]))
#         #                     visited.append(el)
#                             inter = [vertexpos[el] for el in path]
#     #                         print('aaaaaaaaaaaaaaaaaaaaaaaaa')
#                             for v in inter:
#                                 if v not in visited:
#                                     visited.append(v)
#     #                         print([vertexposinv[el] for el in visited], 'b'*10)
#                             J = deepcopy(T)
#                             J.remove_edge(path[-1], path[-2])
#                             nw_pts.pop(nw_pts.index(el))

#                             break
#                         else:
#                             print('aaaaaaaaaaaaaaaaaaaa')
#                             for el in idxs:
#                                 if el in visited:
#                                     print(el,'common')
#             else:
#                 print('no path possible')
#                 breaker = 1
#                 break

# #             else:
# #                 print(vertexposinv[node], vertexposinv[el],'a')

#         print(path, len(path))
#         print('*'*100)

#         if breaker == 1:
#             break
# #         break
#     print('&'*100)
#     path_list.append(path)
#     break

# %% [raw]
# 'This is the cell with infinite loops

# %%
# new_points

# %%
# from itertools import combinations
# from copy import deepcopy

# '''
# visited keeps track of stops in previous paths, that may not be used else infinite loop
# vis_ gets initialised for every new path
# '''
# visited = []
# path_list = []
# for pt in new_points:
#     J = deepcopy(T)    # We initialise a copy of the graph, which initialises for every path
#     vis_in_path = []   # Visited nodes within the path. Refreshes for every new path
#     failed=0
#     if pt not in visited:    # Checking if the starting node has already been visited/lies in some path
#         visited.append(pt)
#         vis_in_path.append(pt)
#         print(pt)
#     #     print(pt)
# #         print(vertexposinv[pt], 'starting point')
#         path = []    #[vertexposinv[pt]
#         nw_pts = deepcopy(new_points)    # A copy of the stops, excluding the starting node
#         nw_pts.pop(nw_pts.index(pt))
#         ctr=0
#         while len(path) <= 99 and failed<500:
#             node = vis_in_path[-1]
# #             print(vertexposinv[node], 'starting node')
# #             print([vertexposinv[el] for el in visited])
#             nearest = 5000
#             dists = []
#             breaker = 0
#             for ver in nw_pts:
#                 temp = math.sqrt((node[0] - ver[0]) ** 2.0 + (node[1] - ver[1]) ** 2.0)
#                 dists.append((ver,temp))
#             dists.sort(key=lambda tup: tup[1])    # List of nodes and their respective distances from the starting node, sorted by distance
#             nbrs = [el[0] for el in dists]    # Indices of the nodes
#             ctr+=1
#             for el in nbrs:
#                 if nx.has_path(J,vertexposinv[node],vertexposinv[el]):    # Checking if path even exists
#                     if el not in vis_in_path:     # Checking if the current node in path has already been visited
#                         if not nx.shortest_path(J,vertexposinv[node],vertexposinv[el]):
#     #                         visited.append(el)
# #                             print('a')
#                             failed+=1
#                         else:    # If path exists, we extend
# #                             print(el, vertexposinv[el], 'neighbor')
# #                             print(dists)
#                             idxs = [vertexposinv[i] for i in vis_in_path]
#                             idxs.pop()
#                             temp_path = list(nx.shortest_path(J,vertexposinv[node],vertexposinv[el]))
# #                             print(idxs,'visited')
# #                             print(temp_path,'new path')
#                             if any(v in temp_path for v in idxs) == False:    # Checking if new potential path doesn't backtrack or form self loops
# #                                 print('not common')
#                                 if path != []:
#                                     path.pop()
#                                 path.extend(nx.shortest_path(J,vertexposinv[node],vertexposinv[el]))    # Path gets updated
#                                 inter = [vertexpos[el] for el in path]
#                                 for v in inter:
#                                     if v not in vis_in_path:    # To remove duplicate nodes in visited nodes in the path
#                                         vis_in_path.append(v)
#                                         if v in new_points and v not in visited:    # For tracking only stops in visited
#                                             visited.append(v)
#         #                         print([vertexposinv[el] for el in visited], 'b'*10)
                                
#                                 J = deepcopy(T)    # Initialise a copy of the original graph
#                                 J.remove_edge(path[-1], path[-2])    # Remove the last edge in the path to ensure no backtracking
#                                 nw_pts.pop(nw_pts.index(el))

#                                 break
#                             else:
# #                                 print('aaaaaaaaaaaaaaaaaaaa')
#                                 failed+=1
#                     else:
#                         failed+=1
# #                                 for el in idxs:
# #                                     if el in vis_in_path:
# #                                         print(el,'common')
                                        
#                 else:    # Break out of the loop if no path can be created; removing this condition creates an infinite loop
# #                     print('no path possible')
#                     breaker = 1
#                     failed+=1
#                     break
# #             print(len(path))
# #             print('*'*100)

#             if breaker == 1:
#                 break
#     #         break
#         path_list.append(path)
#         print([el for el in path if vertexpos[el] in new_points])
#         print('&'*100)
#     else:
#         continue
#     break

# %%
# print(T.nodes(), T.edges())
'''
[2819, 2820, 2824, 2825, 2827, 2828, 2830, 2831, 2832, 2833, 2837, 2838, 2839, 2840, 2841, 2842, 2843, 2844, 2846, 2847, 2848, 2849, 2850, 2851, 2852, 2853, 2856, 2857, 2858, 2859, 2861, 2862, 2863, 2864, 2865, 2866, 2868, 2869, 2870, 2871, 2872, 2873, 2874, 2875, 2876, 2877, 2878, 2879, 2880, 2881, 2882, 2883, 2884, 2885, 2886, 2889, 2890, 2891, 2892, 2893, 2894, 2895, 2897, 2898, 2899, 2900, 2902, 2903, 2904, 2905, 2907, 2909, 2910, 2911, 2912, 2914, 2915, 2916, 2887, 2888, 2901, 2908, 2917, 2913, 2918, 2919, 2920, 2921, 2922, 2923, 2924, 2925, 2926, 2927, 2928, 2930, 2931, 2932, 2933, 2934, 2936, 2937, 2939, 2942, 2943, 2944, 2945, 2948, 2949, 2950, 2951, 2952, 2953, 2954, 2957, 2958, 2959, 2960, 2962, 2963, 2964, 2965, 2966, 2967, 2968, 2970, 2971, 2973, 2975, 2977, 2978, 2979, 2980, 2982, 2984, 2986, 2987, 2988, 2938, 2972, 2946, 2989, 2990, 2991, 2992, 2993, 2995, 2996, 2998, 2999, 3001, 3002, 3003, 3004, 3005, 3006, 3007, 3008, 3010, 3011, 3012, 3013, 3014, 3016, 3018, 3021, 3023, 3025, 3026, 3027, 3028, 3029, 3031, 3032, 3034, 3035, 3036, 3037, 3041, 3043, 3044, 3047, 3050, 3052, 3015, 3033, 3019, 3022, 3020, 3024, 3045, 3030, 3042, 3046, 3053, 3038, 3055, 3056, 3057, 3058, 3059, 3061, 3062, 3065, 3067, 3068, 3069, 3070, 3071, 3072, 3073, 3075, 3076, 3078, 3079, 3081, 3085, 3087, 3089, 3090, 3091, 3092, 3093, 3095, 3096, 3098, 3099, 3101, 3103, 3106, 3107, 3110, 3111, 3113, 3117, 3118, 3119, 3122, 3120, 3064, 3100, 3115, 3123, 3124, 3125, 3126, 3130, 3133, 3135, 3136, 3138, 3139, 3140, 3141, 3145, 3146, 3148, 3150, 3151, 3152, 3155, 3157, 3160, 3163, 3165, 3166, 3170, 3171, 3175, 3176, 3179, 3142, 3173, 3131, 3137, 3149, 3153, 3156, 3158, 3164, 3174, 3178, 3167, 3169, 3181, 3182, 3183, 3186, 3188, 3190, 3193, 3194, 3196, 3199, 3200, 3201, 3203, 3205, 3206, 3207, 3209, 3210, 3212, 3214, 3216, 3219, 3224, 3227, 3230, 3231, 3232, 3235, 3180, 3185, 3195, 3217, 3223, 3228, 3233, 3239, 3242, 3243, 3244, 3245, 3246, 3247, 3249, 3250, 3251, 3252, 3253, 3254, 3256, 3257, 3258, 3259, 3261, 3264, 3265, 3268, 3270, 3274, 3277, 3278, 3279, 3280, 3282, 3283, 3285, 3287, 3238, 3255, 3262, 3271, 3281, 3276, 3289, 3290, 3291, 3292, 3294, 3295, 3297, 3298, 3299, 3300, 3301, 3303, 3305, 3306, 3308, 3313, 3319, 3321, 3322, 3324, 3326, 3327, 3330, 3331, 3336, 3293, 3296, 3304, 3310, 3317, 3325, 3333, 3340, 3342, 3343, 3348, 3349, 3350, 3353, 3355, 3356, 3359, 3360, 3364, 3365, 3366, 3369, 3375, 3376, 3378, 3380, 3382, 3386, 3341, 3351, 3346, 3352, 3368, 3374, 3377, 3345, 3363, 3389, 3390, 3393, 3394, 3395, 3398, 3399, 3403, 3404, 3406, 3407, 3410, 3413, 3414, 3416, 3418, 3421, 3422, 3423, 3424, 3428, 3430, 3433, 3387, 3400, 3408, 3420, 3426, 3432, 3436, 3437, 3440, 3442, 3445, 3446, 3447, 3448, 3453, 3454, 3455, 3457, 3458, 3460, 3463, 3466, 3467, 3471, 3474, 3476, 3441, 3459, 3462, 3465, 3473, 3478, 3480, 3482, 3484, 3485, 3487, 3489, 3490, 3491, 3492, 3493, 3494, 3500, 3501, 3506, 3510, 3516, 3496, 3512, 3503, 3507, 3486, 3498, 3509, 3514, 3518, 3519, 3520, 3521, 3522, 3523, 3526, 3527, 3528, 3529, 3530, 3531, 3535, 3537, 3540, 3543, 3548, 3550, 3552, 3555, 3557, 3560, 3524, 3536, 3553, 3559, 3561, 3562, 3563, 3565, 3568, 3569, 3570, 3571, 3573, 3574, 3577, 3578, 3580, 3581, 3582, 3585, 3587, 3589, 3593, 3564, 3572, 3576, 3584, 3597, 3599, 3601, 3603, 3605, 3607, 3609, 3612, 3613, 3615, 3616, 3619, 3620, 3624, 3625, 3629, 3633, 3634, 3600, 3606, 3610, 3614, 3622, 3627, 3631, 3604, 3618, 3637, 3638, 3640, 3642, 3643, 3645, 3648, 3649, 3652, 3655, 3657, 3660, 3662, 3646, 3664, 3635, 3651, 3654, 3666, 3659, 3670, 3671, 3672, 3674, 3675, 3677, 3680, 3682, 3683, 3685, 3689, 3690, 3693, 3698, 3703, 3700, 3686, 3691, 3697, 3702, 3704, 3705, 3706, 3708, 3709, 3710, 3711, 3712, 3715, 3716, 3718, 3723, 3724, 3725, 3729, 3733, 3720, 3728, 3731, 3713, 3734, 3735, 3736, 3737, 3739, 3740, 3741, 3743, 3745, 3747, 3749, 3751, 3755, 3759, 3748, 3738, 3744, 3757, 3054, 3074, 3121, 3191, 3240, 3371, 3417, 3438, 3439, 3479, 3567, 3673, 3678, 3707, 3760, 3761, 3762, 3763, 3765, 3766, 3767, 3768, 3770, 3771, 3773, 3774, 3776, 3778, 3786]
'''
'''
[(2819, 2850), (2819, 2851), (2820, 2852), (2820, 2853), (2824, 2862), (2824, 2863), (2825, 2864), (2825, 2865), (2827, 2868), (2827, 2869), (2828, 2870), (2828, 2871), (2830, 2874), (2830, 2875), (2830, 2876), (2830, 2877), (2831, 2878), (2831, 2879), (2832, 2880), (2832, 2881), (2833, 2882), (2833, 2883), (2837, 2890), (2837, 2891), (2838, 2892), (2838, 2893), (2839, 2894), (2839, 2895), (2840, 2897), (2840, 3205), (2841, 2898), (2841, 2899), (2842, 2900), (2842, 2901), (2843, 2902), (2843, 2903), (2843, 2904), (2843, 2905), (2844, 2907), (2844, 3110), (2846, 2910), (2846, 2911), (2847, 2912), (2847, 2913), (2848, 2914), (2848, 2915), (2849, 2916), (2849, 2917), (2850, 2918), (2851, 2919), (2852, 2920), (2852, 3330), (2852, 3185), (2853, 2921), (2856, 2924), (2856, 3686), (2857, 2925), (2857, 3686), (2858, 2926), (2858, 3375), (2858, 3697), (2859, 2927), (2859, 3375), (2861, 3698), (2861, 3715), (2862, 2930), (2863, 2931), (2864, 2932), (2865, 2933), (2865, 3117), (2865, 2946), (2866, 2934), (2866, 3294), (2868, 2936), (2869, 2937), (2869, 3666), (2870, 2938), (2871, 2939), (2872, 3553), (2872, 3473), (2873, 3627), (2873, 3553), (2874, 2942), (2875, 2943), (2876, 2944), (2877, 2945), (2878, 2946), (2878, 3466), (2878, 3346), (2879, 3333), (2879, 3223), (2880, 2948), (2881, 2949), (2881, 3276), (2881, 3131), (2882, 2950), (2883, 2951), (2884, 2952), (2884, 3664), (2885, 2953), (2885, 3664), (2886, 2954), (2886, 3728), (2889, 2957), (2889, 3331), (2889, 3195), (2889, 3406), (2890, 2958), (2890, 3510), (2890, 3624), (2890, 3524), (2891, 2959), (2892, 2960), (2893, 3622), (2894, 2962), (2895, 2963), (2897, 2965), (2898, 2966), (2899, 2967), (2900, 2968), (2902, 2970), (2903, 2971), (2904, 2972), (2904, 3283), (2904, 3164), (2905, 2973), (2907, 2975), (2907, 3053), (2907, 2913), (2909, 2977), (2909, 3053), (2909, 3716), (2910, 2978), (2910, 3755), (2910, 3691), (2911, 2979), (2912, 2980), (2914, 2982), (2915, 3432), (2916, 2984), (2887, 2986), (2887, 3728), (2888, 2986), (2888, 3406), (2901, 2987), (2901, 3518), (2901, 3122), (2908, 2987), (2908, 3175), (2908, 3042), (2908, 3716), (2917, 2988), (2918, 2989), (2919, 2990), (2920, 2991), (2921, 2992), (2922, 2993), (2922, 3731), (2923, 3662), (2923, 3584), (2924, 2995), (2925, 2996), (2926, 3336), (2927, 2998), (2928, 2999), (2928, 3720), (2930, 3001), (2931, 3002), (2932, 3003), (2933, 3004), (2934, 3005), (2936, 3007), (2937, 3008), (2939, 3010), (2939, 3691), (2939, 3606), (2942, 3013), (2943, 3014), (2944, 3015), (2945, 3016), (2948, 3019), (2948, 3759), (2948, 3368), (2949, 3020), (2950, 3021), (2951, 3022), (2951, 3285), (2951, 3178), (2952, 3023), (2953, 3024), (2954, 3025), (2954, 3610), (2957, 3026), (2958, 3027), (2958, 3279), (2958, 3149), (2959, 3028), (2960, 3029), (2962, 3031), (2963, 3032), (2964, 3033), (2964, 3205), (2965, 3034), (2966, 3035), (2967, 3036), (2968, 3037), (2968, 3281), (2968, 3156), (2970, 3038), (2970, 3176), (2970, 3046), (2971, 3426), (2971, 3325), (2973, 3041), (2975, 3042), (2977, 3043), (2977, 3174), (2977, 3030), (2978, 3044), (2979, 3045), (2979, 3262), (2980, 3046), (2982, 3047), (2982, 3631), (2982, 3174), (2984, 3121), (2986, 3050), (2987, 3122), (2988, 3052), (2988, 3110), (2938, 3054), (2972, 3054), (2989, 3055), (2989, 3280), (2989, 3153), (2990, 3056), (2991, 3057), (2992, 3058), (2993, 3059), (2995, 3061), (2995, 3724), (2995, 3635), (2996, 3062), (2998, 3064), (2999, 3065), (3001, 3067), (3001, 3382), (3002, 3068), (3003, 3069), (3004, 3070), (3005, 3071), (3006, 3072), (3006, 3476), (3006, 3629), (3006, 3345), (3006, 3363), (3007, 3073), (3008, 3074), (3010, 3075), (3011, 3076), (3011, 3473), (3012, 3627), (3013, 3078), (3014, 3079), (3016, 3081), (3016, 3467), (3016, 3352), (3018, 3428), (3018, 3333), (3021, 3085), (3021, 3231), (3021, 3064), (3023, 3087), (3025, 3089), (3026, 3090), (3027, 3091), (3028, 3092), (3029, 3093), (3031, 3095), (3032, 3096), (3034, 3098), (3034, 3548), (3034, 3441), (3035, 3099), (3036, 3100), (3037, 3101), (3041, 3755), (3043, 3106), (3043, 3400), (3044, 3107), (3047, 3110), (3050, 3113), (3050, 3277), (3050, 3137), (3052, 3115), (3015, 3118), (3015, 3550), (3015, 3459), (3033, 3118), (3019, 3119), (3019, 3233), (3019, 3115), (3022, 3119), (3020, 3120), (3024, 3120), (3024, 3179), (3024, 3420), (3045, 3122), (3030, 3622), (3053, 3744), (3038, 3121), (3038, 3424), (3038, 3310), (3055, 3123), (3056, 3124), (3057, 3125), (3058, 3126), (3059, 3697), (3061, 3238), (3062, 3130), (3065, 3133), (3065, 3552), (3065, 3465), (3067, 3135), (3067, 3180), (3068, 3136), (3069, 3137), (3069, 3282), (3069, 3158), (3070, 3138), (3070, 3139), (3070, 3509), (3071, 3139), (3072, 3140), (3072, 3486), (3073, 3141), (3075, 3142), (3076, 3317), (3078, 3355), (3079, 3145), (3081, 3146), (3085, 3148), (3087, 3149), (3089, 3150), (3090, 3151), (3091, 3152), (3092, 3153), (3093, 3548), (3095, 3155), (3096, 3156), (3098, 3157), (3099, 3158), (3101, 3160), (3103, 3512), (3103, 3228), (3103, 3426), (3106, 3163), (3107, 3164), (3110, 3165), (3111, 3166), (3111, 3618), (3113, 3167), (3117, 3169), (3118, 3170), (3119, 3171), (3122, 3173), (3120, 3179), (3100, 3618), (3123, 3180), (3123, 3471), (3123, 3377), (3124, 3181), (3125, 3182), (3126, 3183), (3130, 3186), (3133, 3188), (3135, 3190), (3136, 3191), (3138, 3193), (3139, 3194), (3139, 3474), (3140, 3195), (3141, 3196), (3141, 3278), (3141, 3462), (3145, 3200), (3146, 3201), (3148, 3203), (3150, 3205), (3151, 3206), (3152, 3207), (3155, 3210), (3157, 3212), (3160, 3214), (3163, 3217), (3165, 3219), (3166, 3597), (3170, 3223), (3171, 3224), (3175, 3227), (3176, 3228), (3179, 3230), (3179, 3555), (3142, 3235), (3173, 3235), (3131, 3374), (3153, 3421), (3153, 3293), (3178, 3121), (3167, 3169), (3169, 3287), (3181, 3238), (3182, 3239), (3183, 3240), (3186, 3242), (3188, 3243), (3190, 3245), (3190, 3377), (3190, 3255), (3193, 3246), (3194, 3247), (3196, 3249), (3196, 3738), (3199, 3250), (3199, 3355), (3200, 3251), (3201, 3252), (3203, 3253), (3205, 3254), (3206, 3255), (3207, 3256), (3209, 3257), (3209, 3548), (3210, 3258), (3210, 3625), (3210, 3536), (3212, 3259), (3214, 3473), (3216, 3262), (3216, 3755), (3219, 3264), (3224, 3233), (3224, 3410), (3224, 3576), (3227, 3268), (3227, 3593), (3227, 3518), (3230, 3270), (3231, 3271), (3232, 3618), (3232, 3557), (3235, 3274), (3235, 3430), (3235, 3317), (3185, 3238), (3217, 3432), (3239, 3289), (3242, 3290), (3243, 3291), (3244, 3292), (3244, 3380), (3244, 3271), (3244, 3702), (3244, 3516), (3245, 3293), (3246, 3294), (3247, 3295), (3249, 3296), (3250, 3297), (3251, 3298), (3252, 3299), (3253, 3300), (3254, 3301), (3254, 3423), (3254, 3304), (3256, 3303), (3257, 3304), (3258, 3305), (3259, 3306), (3261, 3308), (3261, 3559), (3264, 3310), (3265, 3664), (3265, 3597), (3268, 3313), (3270, 3359), (3274, 3317), (3274, 3281), (3277, 3319), (3279, 3321), (3280, 3322), (3282, 3324), (3283, 3325), (3285, 3327), (3287, 3509), (3287, 3408), (3238, 3376), (3238, 3713), (3276, 3386), (3276, 3557), (3289, 3340), (3290, 3341), (3291, 3342), (3292, 3343), (3294, 3345), (3294, 3657), (3295, 3346), (3297, 3348), (3298, 3349), (3298, 3422), (3298, 3296), (3299, 3350), (3299, 3693), (3299, 3614), (3300, 3351), (3301, 3352), (3303, 3353), (3305, 3355), (3306, 3356), (3308, 3516), (3313, 3360), (3319, 3363), (3321, 3364), (3322, 3365), (3324, 3366), (3326, 3368), (3326, 3631), (3327, 3369), (3330, 3371), (3331, 3654), (3336, 3374), (3340, 3387), (3342, 3389), (3343, 3390), (3348, 3393), (3349, 3394), (3350, 3395), (3353, 3398), (3355, 3399), (3356, 3400), (3359, 3664), (3359, 3633), (3359, 3723), (3360, 3403), (3364, 3406), (3365, 3407), (3365, 3507), (3365, 3387), (3366, 3408), (3369, 3410), (3375, 3413), (3375, 3576), (3376, 3414), (3378, 3416), (3378, 3473), (3380, 3417), (3382, 3418), (3386, 3420), (3341, 3433), (3351, 3433), (3389, 3436), (3390, 3437), (3393, 3438), (3394, 3439), (3395, 3440), (3398, 3441), (3399, 3442), (3403, 3445), (3404, 3446), (3404, 3723), (3406, 3447), (3407, 3448), (3410, 3576), (3413, 3697), (3414, 3453), (3416, 3454), (3418, 3455), (3421, 3457), (3422, 3458), (3423, 3459), (3424, 3460), (3428, 3462), (3430, 3463), (3433, 3465), (3400, 3729), (3400, 3622), (3432, 3618), (3436, 3478), (3437, 3479), (3440, 3480), (3442, 3482), (3445, 3484), (3446, 3485), (3447, 3486), (3448, 3487), (3453, 3490), (3454, 3491), (3455, 3492), (3457, 3493), (3458, 3494), (3460, 3496), (3463, 3498), (3466, 3500), (3467, 3501), (3471, 3503), (3474, 3666), (3476, 3506), (3478, 3519), (3480, 3520), (3482, 3521), (3484, 3523), (3485, 3524), (3487, 3526), (3489, 3527), (3489, 3697), (3490, 3528), (3491, 3529), (3491, 3589), (3491, 3498), (3492, 3530), (3492, 3725), (3492, 3651), (3493, 3531), (3494, 3670), (3500, 3535), (3501, 3536), (3506, 3540), (3510, 3543), (3516, 3702), (3496, 3559), (3512, 3559), (3503, 3560), (3507, 3560), (3514, 3757), (3514, 3702), (3519, 3561), (3520, 3562), (3521, 3563), (3522, 3564), (3522, 3659), (3523, 3565), (3526, 3567), (3527, 3568), (3528, 3569), (3529, 3570), (3530, 3571), (3531, 3572), (3535, 3574), (3537, 3576), (3537, 3778), (3540, 3577), (3543, 3578), (3548, 3580), (3550, 3581), (3552, 3582), (3555, 3584), (3557, 3585), (3560, 3587), (3561, 3599), (3562, 3600), (3563, 3601), (3565, 3603), (3568, 3604), (3569, 3605), (3570, 3606), (3571, 3607), (3573, 3609), (3573, 3670), (3574, 3610), (3577, 3612), (3578, 3613), (3580, 3614), (3581, 3615), (3582, 3616), (3585, 3618), (3587, 3619), (3589, 3620), (3593, 3622), (3593, 3690), (3593, 3600), (3564, 3634), (3572, 3634), (3584, 3700), (3584, 3604), (3599, 3635), (3601, 3637), (3603, 3638), (3605, 3640), (3607, 3642), (3609, 3643), (3612, 3645), (3613, 3646), (3615, 3648), (3616, 3649), (3619, 3651), (3620, 3652), (3624, 3654), (3625, 3655), (3629, 3657), (3633, 3659), (3634, 3660), (3637, 3670), (3638, 3671), (3640, 3672), (3642, 3673), (3643, 3674), (3645, 3675), (3648, 3677), (3649, 3678), (3652, 3680), (3655, 3682), (3657, 3683), (3660, 3685), (3662, 3686), (3646, 3703), (3664, 3703), (3659, 3733), (3670, 3704), (3671, 3705), (3672, 3706), (3674, 3707), (3675, 3708), (3677, 3709), (3680, 3710), (3682, 3711), (3683, 3712), (3685, 3713), (3689, 3715), (3689, 3757), (3690, 3716), (3693, 3718), (3698, 3720), (3703, 3723), (3700, 3733), (3686, 3731), (3704, 3734), (3705, 3735), (3706, 3736), (3708, 3737), (3709, 3738), (3710, 3739), (3711, 3740), (3712, 3741), (3715, 3743), (3716, 3744), (3718, 3745), (3723, 3747), (3724, 3748), (3725, 3749), (3729, 3751), (3733, 3786), (3734, 3760), (3735, 3761), (3736, 3762), (3737, 3763), (3739, 3765), (3740, 3766), (3741, 3767), (3743, 3768), (3745, 3770), (3747, 3771), (3749, 3773), (3751, 3774), (3755, 3776), (3759, 3778), (3748, 3786)]
'''
print('a')
# Out:
# a

# %%
from itertools import combinations
from copy import deepcopy

'''
visited keeps track of stops in previous paths, that may not be used else infinite loop
vis_ gets initialised for every new path
'''
visited = []
path_list = []

paths = []
for n1, n2 in combinations(new_points, 2):
    paths.append(nx.shortest_path(T, vertexposinv[n1], vertexposinv[n2]))
# # print(len(paths))

'''
for pts in new_points, split into pairs (preferably diametrically opposite)
try to grow shortest path between pairs, including 
'''
path_list = []
for pt in new_points:
    direction = (200-pt[0], 200-pt[1])
#     print(pt, direction)
    nearest = 5000
    best_pt = None
    for ver in new_points:
        temp = math.sqrt((direction[0] - ver[0]) ** 2.0 + (direction[1] - ver[1]) ** 2.0)
#             vvv = temp#(1/vertexdem[ver[::-1]])*temp
        if temp < nearest:
            best_pt = ver
            nearest = temp
#         print(pt, direction, best_pt)
    
    path_list.append(nx.shortest_path(T,vertexposinv[pt],vertexposinv[best_pt]))

print(len(path_list))

removed = []
for i in range(len(path_list)):
    for j in range(i+1,len(path_list)):
        temp_1 = None
        temp_2 = None
        if len(path_list[i]) >= len(path_list[j]):
            temp_1 = path_list[i]
            temp_2 = path_list[j]
        else:
            temp_1 = path_list[j]
            temp_2 = path_list[i]
        if len(set(temp_1).intersection(set(temp_2))) >= 0.65*len(temp_2):
            if temp_2 not in removed:
                removed.append(temp_2)

print(len(removed))
for i in removed:
#     if i in path_list:
#         print('a')
    path_list.remove(i)
    

print(len(path_list))

'''
look at all remaining stops
pick end node of path, iteratively connect to nearest stop until cannot find more

'''
# Out:
# 114
# 97
# 17
# '\nlook at all remaining stops\npick end node of path, iteratively connect to nearest stop until cannot find more\n\n'

# %%
covered = []
for path in path_list:
    for el in path:
#         print(vertexpos[el])
#         print(el)
        if el not in covered and vertexpos[el] in new_points:
            covered.append(el)
remaining = [vertexposinv[el] for el in new_points]
# print(remaining)
for pt in covered:
    remaining.remove(pt)
# temp = 0
print(remaining)

# vis = []
# for path in path_list:
#     for el not in vis and el in path:
#         if el in new_points:
            

longest = []
for n1, n2 in combinations(remaining,2):
    pth = nx.shortest_path(T, n1, n2)
    if any(i in covered for i in pth) == False:
        if len(pth) >= len(longest):
            longest = pth

print(len(longest), longest)
# Out:
# [18645, 19119, 18655, 18975, 18810, 19559, 19298, 19350, 18803, 18729, 18663, 18665, 18768, 18846, 18863, 19018, 19066, 19070, 19118, 19148, 19200, 19438, 19529, 19543, 19597, 18972]
# 14 [19119, 19067, 19014, 18953, 18886, 18810, 18733, 18665, 18732, 18809, 18780, 18703, 18655, 19543]

# %%
# from itertools import combinations
# from copy import deepcopy
# # print(new_points)
# # print(len(new_points))
# # combs = list(combinations(new_points, 2))
# # # print(temp)
# # connec = {}
# # for p1, p2 in combs:
# #     connec[(vertexposinv[p1], vertexposinv[p2])] = len(list(nx.all_shortest_paths(G, vertexposinv[p1], vertexposinv[p2])))
# # print(connec)

# '''
# Ignore blue nodes
# Pick sets of points
# Make shortest path containing all nodes in a subset
# Make a few shortest paths like this, for different subsets
# '''
# visited = []
# path_list = []
# for pt in new_points:
#     J = deepcopy(G)
#     visited.append(pt)
# #     print(vertexposinv[pt])
#     path = []    #[vertexposinv[pt]
#     nw_pts = deepcopy(new_points)
#     nw_pts.pop(nw_pts.index(pt))
#     while len(path) <= 50:
#         if path != []:
#             path.pop()
#         node = visited[-1]
# #         print(vertexposinv[node], 'a')
#         nearest = 5000
#         best_pt = None
#         for ver in nw_pts:
#             temp = math.sqrt((node[0] - ver[0]) ** 2.0 + (node[1] - ver[1]) ** 2.0)
# #             vvv = temp#(1/vertexdem[ver[::-1]])*temp
#             if temp < nearest:
#                 best_pt = ver
#                 nearest = temp
#         visited.append(best_pt)
#         if best_pt is not None:
# #             sub_paths = list(nx.all_shortest_paths(G,vertexposinv[node],vertexposinv[best_pt]))
# #             if len(sub_paths) > 1:
# #                 for p in sub_paths:
# #                     idces = [vertexpos[el] for el in p]
# #                     if set(visited).intersection(set(idces)):
# #                         continue
# #                     else:
# #                         path.extend(p)
# #             elif len(sub_paths) == 1:
# # #                 if any(n not in visited for n in p):
# # #                     path.extend(p)
#             path.extend(nx.shortest_path(J,vertexposinv[node],vertexposinv[best_pt]))
# #             sub_paths = list(nx.all_shortest_paths(G,vertexposinv[node],vertexposinv[best_pt]))
# #             if len(sub_paths) > 1:
# #         J = deepcopy(G)
# #         sub_paths = list(nx.all_shortest_paths(J,vertexposinv[node],vertexposinv[best_pt]))
# #         if len(sub_paths) > 1:
# #         J.remove_edge(path[-1], path[-2])

#         nw_pts.pop(nw_pts.index(best_pt))
# #         print(path)
# #         break
# #     print('*'*100)
#     path_list.append(path)
# #     break

# # nx.draw(J, vertexpos, node_size=10, font_size=8)
# # print(path_list)

# '''
# 89
# '''

# # path_list = []
# # for ver in new_points:
# #     path = []
# #     visited = []
# #     idx = vertexposinv[ver]
# #     visited.append(idx)
# #     path.append(idx)
# # #     print(visited)
# # #     seen=[]
# #     while len(path) <= 99:
# # #         print(visited)
# #         c+=1
# # #         print(path[-1])
# #         best_nd = None
# #         best_dem = 0
# #         nbs = list(H.neighbors(path[-1]))
# # #         print(nbs)
# #         for nb in nbs:
# # #             print(nb)
# #             if nb not in visited:
# #     #                 print(best_nd)
# #                 ids = vertexpos[nb]
# # #                 print(vertexdem[ids[::-1]])
# #                 if vertexdem[ids[::-1]] > best_dem:
# #                     best_dem = vertexdem[ids[::-1]]
# #                     best_nd = nb
# #                     visited.append(best_nd)
# #                 else:
# #                     visited.append(nb)
# #             else:
# #                 continue
# # #         print(best_nd)
# #         if best_nd is not None:
# #             path.append(best_nd)
# #         else:
# #             break
# # #             visited.append(best_nd)
# # #         print("*"*100)
# # #     print(len(path))
# #     path_list.append(path)

# # print(path_list)

# %%
# from copy import deepcopy

# H = deepcopy(G)

# # print(new_points)
# path_list = []


# for ver in new_points:
#     path = []
#     visited = []
#     idx = vertexposinv[ver]
#     visited.append(idx)
#     path.append(idx)
#     c=0
# #     print(visited)
# #     seen=[]
#     while len(path) <= 99:
# #         print(visited)
#         c+=1
# #         print(path[-1])
#         best_nd = None
#         best_dem = 0
#         nbs = list(H.neighbors(path[-1]))
# #         print(nbs)
#         for nb in nbs:
# #             print(nb)
#             if nb not in visited:
#     #                 print(best_nd)
#                 ids = vertexpos[nb]
# #                 print(vertexdem[ids[::-1]])
#                 if vertexdem[ids[::-1]] > best_dem:
#                     best_dem = vertexdem[ids[::-1]]
#                     best_nd = nb
#                     visited.append(best_nd)
#                 else:
#                     visited.append(nb)
#             else:
#                 continue
# #         print(best_nd)
#         if best_nd is not None:
#             path.append(best_nd)
#         else:
#             break
# #             visited.append(best_nd)
# #         print("*"*100)
# #     print(len(path))
#     path_list.append(path)
#         # find nb with max dem ( while finding max also check it should not be in visited)
#         #add to path path.append(nb)

# '''
# FOUND A BUG: lOTS OF PATHS JUST ALTERNATING BETWEEN TWO VERTICES
# '''        

# # print(path_list)
# for p in path_list:
#     print(len(p))

# %%
# # from copy import deepcopy
# #[3012, 3548]
# # H = deepcopy(G)

# # # print(new_points)
# # path_list = []
# visited = []

# # # for ver in new_points:
# path = []
# #     idx = vertexposinv[ver]
# #     visited.append(idx)
# path.append(3548)
# visited.append(3548)
# c=0
# #     print(visited)
# #     seen=[]
# while len(path) <= 25:
#     print(visited)
#     c+=1
#     print(path[-1])
#     best_nd = None
#     best_dem = 0
#     nbs = list(H.neighbors(path[-1]))
#     print(nbs)
#     for nb in nbs:
#         print(nb)
#         if nb not in visited:
# #                 print(best_nd)
#             ids = vertexpos[nb]
#             print(vertexdem[ids[::-1]])
#             if vertexdem[ids[::-1]] > best_dem:
#                 best_dem = vertexdem[ids[::-1]]
#                 best_nd = nb
#                 visited.append(best_nd)
#             else:
#                 visited.append(nb)
#         else:
#             continue
#     print(best_nd)
#     if best_nd is not None:
#         path.append(best_nd)
#     else:
#         break
# #             visited.append(best_nd)
#     print("*"*100)
# path_list.append(path)
#         # find nb with max dem ( while finding max also check it should not be in visited)
#         #add to path path.append(nb)

# # '''
# # FOUND A BUG: lOTS OF PATHS JUST ALTERNATING BETWEEN TWO VERTICES
# # '''        

# # print(path_list)
# # for path in path_list:
# #     print(path)

# %%
# paths = []
# for n1, n2 in combinations(new_points, 2):
#     paths.append(nx.shortest_path(T, vertexposinv[n1], vertexposinv[n2]))
# print(len(paths))

# %%
# print(list(G.neighbors(86)))
# nbs = H.neighbors(3012)
# #         print(list(nbs))
# for nb in list(nbs):
# #             print(nb)
# #             if nb not in visited:
# #                 print(best_nd)
#     ids = vertexpos[nb]
#     print(nb)
#     print(vertexdem[ids[::-1]])

# %%
fig, ax = plt.subplots(figsize=(20,20))
ax.scatter(x_co, y_co, c='#00ff00', alpha = 1.0)
for i, txt in enumerate(labels):
    ax.annotate(txt, (x_co[i], y_co[i]))
nx.draw(T, vertexpos, node_size=15, font_size=10)
'''
[1, 200, 222, 669, 137, 752, 381, 232, 199, 63, 602, 230, 205, 546, 37, 405, 272, 754, 204, 862, 151, 69, 13, 150, 613, 901, 506, 836, 311, 635, 417, 220, 610, 524, 860, 503]
'''
# Out:
# '\n[1, 200, 222, 669, 137, 752, 381, 232, 199, 63, 602, 230, 205, 546, 37, 405, 272, 754, 204, 862, 151, 69, 13, 150, 613, 901, 506, 836, 311, 635, 417, 220, 610, 524, 860, 503]\n'

# %%
rem_x_co = []
rem_y_co = []
for ver in remaining:
    rem_x_co.append(vertexpos[ver][0])
    rem_y_co.append(vertexpos[ver][1])

plt.figure(figsize=(10,10))
plt.scatter(x_co, y_co, c='#00ff00', alpha = 1.0)
plt.scatter(rem_x_co, rem_y_co, c='#ff0000', alpha = 1.0)
nx.draw(T, vertexpos, node_size=10, font_size=8,width=0.5)

# %%
def get_cmap(n, name='hsv'):
    return plt.cm.get_cmap(name, n)

P = nx.Graph()
edges = []
for path in path_list:
    path_edges = [(path[n], path[n+1]) for n in range(len(path)-1)]
    P.add_nodes_from(path)
    P.add_edges_from(path_edges)
    edges.append(path_edges)

# nx.draw(P)
pos = nx.spring_layout(P)
# nx.draw(P, pos)
colors = get_cmap(len(path_list))

# colors = [i for i in range(len(path_list))]
linewidths = [2*i for i in range(len(path_list))]
# print(len(path_list))
# print(colors,linewidths)

# nx.draw_networkx_labels(P,pos=pos)

# fig, ax = plt.subplots(figsize=(12,12))
# ax.scatter(x_co, y_co, c='#00ff00', alpha = 1.0)
# for i, txt in enumerate(labels):
#     ax.annotate(txt, (x_co[i], y_co[i]))
# nx.draw(G, vertexpos, node_size=10, font_size=8)

plt.figure(figsize=(10,10))

nx.draw(T, vertexpos, node_size=10, font_size=8,width=0.5)

cm = plt.get_cmap('gist_rainbow')
NUM_COLORS=len(edges)
for ctr, edgelist in enumerate(edges):
#     plt.figure(figsize=(5,5))
#     nx.draw(T, vertexpos, node_size=10, font_size=8, width=0.5)

#     print(edgelist)

#     print(edgelist)
    plt.scatter(x_co, y_co, c='#000000', alpha = 1.0)
    plt.scatter(rem_x_co, rem_y_co, c='#ff0000', alpha = 1.0)
    nx.draw_networkx_edges(P, pos=vertexpos, edgelist=edgelist, edge_color = cm(ctr//3*3.0/NUM_COLORS), width = 4 ,node_size= 10)
#     plt.show()
plt.show()
# plt.savefig('this.png')

# %%
pos = nx.spring_layout(P)
colors = get_cmap(len(path_list))
linewidths = [2*i for i in range(len(path_list))]

plt.figure(figsize=(20,20))

nx.draw(T, vertexpos, node_size=10, font_size=8, alpha=0.3, width=0.5)

cm = plt.get_cmap('gist_rainbow')
NUM_COLORS=len(edges)
for ctr, edgelist in enumerate(edges):
    plt.scatter(x_co, y_co, c='#000000', alpha = 1.0)
    plt.scatter(rem_x_co, rem_y_co, c='#FFA500', alpha = 1.0)
    nx.draw_networkx_edges(P, pos=vertexpos, edgelist=edgelist, edge_color = cm(ctr//3*3.0/NUM_COLORS), alpha = 0.3, width = 4 ,node_size= 10)

plt.savefig('paths.png')
plt.show()

# %%
# print(remaining)
# print(path_list[7])
# Out:
# [2091, 2083, 2225, 2834, 2223, 2048, 2220, 2372, 2432, 2480, 2505, 2534, 2641, 2701, 2814, 2842, 2894, 2903]
# [2252, 2188, 2115, 2047, 2832, 2045, 2161, 2222, 2292, 2738, 2715, 2111, 2108, 2270, 2210, 2144, 2639, 2683, 2646, 2604, 2831, 2801, 2773, 2744, 2532, 2573, 2612, 2654, 2256, 2743, 2772, 2800, 2543, 2580, 2102, 2034, 2003, 2036, 2104, 2178, 2242, 2302]

# %%
'''
path extension
find closest node to extend path
ensure that there are no loops
repeat until path cannot be extended (either everything in visited or no existing path)
'''

new_paths = deepcopy(path_list)
updated_paths = []
cov = []

# make visited

# vis = []

for path in new_paths:
    Q=deepcopy(T)
    possible = []
    Q.remove_edge(path[-1], path[-2])
    new = deepcopy(path)
    for pt in remaining:
        closest = pt
        if nx.has_path(Q, path[-1], pt):# and pt not in vis:
            temp = nx.shortest_path(Q, path[-1], pt)
            temp.pop(0)
            if any(i in temp for i in path) == False:
                possible.append(temp)
                cov.append(pt)
#                 vis.append(pt)
    if possible != []:
        possible.sort(key = len)
        extenx = possible[0]
        print(len(extenx), 'a')
        new.extend(extenx)
#         updated_paths.append(path)
    possible = []
    
    Q.remove_edge(path[0], path[1])
    for pt in remaining:
        closest = pt
        if nx.has_path(Q, path[0], pt):# and pt not in vis:
            temp = nx.shortest_path(Q, pt, path[0])
            temp.pop(-1)
            if any(i in temp for i in path) == False:
                possible.append(temp)
                cov.append(pt)
#                 vis.append(pt)
    if possible != []:
        possible.sort(key = len)
        extenx = possible[0]
        print(len(extenx), 'b')
        new = extenx + new
#         updated_paths.append(extenx)
    else:
        print('aaaaaaaaaaaaaaaaaaaa')
    if len(path) != len(new):
        updated_paths.append(new)
    
#     for el in remaining:
#         if el in vis:
#             remaining.pop(remaining.index(el))

# print(new_paths)
            
updated = new_paths[0]

Y = nx.Graph()
ejs = []
for path in updated_paths:
    ej = [(path[n], path[n+1]) for n in range(len(path)-1)]
    Y.add_nodes_from(path)
    Y.add_edges_from(ej)
    ejs.append(ej)

cm = plt.get_cmap('gist_rainbow')
NUM_COLORS=len(ejs)

# ej = [(updated[n], updated[n+1]) for n in range(len(updated)-1)]
# Y.add_nodes_from(updated)
# Y.add_edges_from(ej)
# ejs.append(ej)

plt.figure(figsize=(10,10))
plt.scatter(x_co, y_co, c='#0000ff', alpha = 0.3)
# plt.scatter(rem_x_co, rem_y_co, c='#000000', alpha = 1.0)
nx.draw(T, vertexpos, node_size=10, font_size=8,width=0.5)
    
for ctr, edgelist in enumerate(ejs):
#     plt.figure(figsize=(10,10))
# #     plt.scatter(x_co, y_co, c='#0000ff', alpha = 0.3)
#     plt.scatter(rem_x_co, rem_y_co, c='#000000', alpha = 1.0)
#     nx.draw(T, vertexpos, node_size=10, font_size=8,width=0.5)
    nx.draw_networkx_edges(Y, pos=vertexpos, edgelist=edgelist, edge_color = cm(ctr//3*3.0/NUM_COLORS), alpha = 0.5, width = 4 ,node_size= 10)
#     plt.show()
plt.show()
# Out:
# 3 a
# 12 b
# 9 b
# 3 a
# 5 b
# 12 a
# 4 b
# 9 a
# 3 b
# 12 a
# aaaaaaaaaaaaaaaaaaaa
# 1 a
# aaaaaaaaaaaaaaaaaaaa
# 10 a
# 6 b
# 21 a
# 3 b
# 3 a
# 14 b
# 10 a
# 10 b
# 10 a
# 8 b
# 5 a
# 4 b
# 3 a
# 15 b

# %%
line_pool = {}
period = 10
pool = []
dist_id = []
for path in path_list:
# for path in updated_paths:
#     print(len(path),'a')
    stops = []
    dists = []
    for p in range(len(path)):
        if vertexpos[path[p]] in new_points:
            stops.append(path[p])
            dists.append(p)
#     print(len(stops),'b')
    dist_id.append(dists)
    pool.append(stops)

print(pool[0])
# print(dists)
start = 6.0
for i in range(len(pool)):
    times = [start + t/50 for t in dist_id[i]]
    line_pool.update({tuple(pool[i]):(start, times)})
# print(line_pool)

'''
Feasible paths
'''
# Out:
# [2762, 2095, 2355, 2002, 2030, 2073, 2142, 2325, 2374, 2423, 2639, 2625, 2293, 2184, 2042, 2183, 2247, 2709, 2219]
# '\nFeasible paths\n'

# %%
L = nx.Graph()
edjs = []

for line in line_pool.keys():
#     print(list(line))
    temp = list(line)
    edj = [(temp[n], temp[n+1]) for n in range(len(temp)-1)]
#     print(edj)
    L.add_nodes_from(path)
    L.add_edges_from(ej)
    edjs.append(edj)

cm = plt.get_cmap('gist_rainbow')
NUM_COLORS=len(edjs)

cov_x = []
cov_y = []
for ver in covered:
    cov_x.append(vertexpos[ver][0])
    cov_y.append(vertexpos[ver][1])

# fig, ax = plt.subplots(figsize=(20,20))
# ax.scatter(x_co, y_co, c='#00ff00', alpha = 1.0)
# for i, txt in enumerate(labels):
#     ax.annotate(txt, (x_co[i], y_co[i]))
# nx.draw(T, vertexpos, node_size=15, font_size=10)

plt.figure(figsize=(10,10))
plt.scatter(cov_x, cov_y, c='#000000', alpha = 1.0)
    
for ctr, edgelist in enumerate(edjs):
    nx.draw_networkx_edges(L, pos=vertexpos, edgelist=edgelist, edge_color = cm(ctr//3*3.0/NUM_COLORS), alpha = 0.5, width = 4 ,node_size= 10)
plt.show()

# %%
for ctr, edgelist in enumerate(edjs):
    plt.figure(figsize=(10,10))
    plt.scatter(cov_x, cov_y, c='#000000', alpha = 0.2)
#     nx.draw(T, vertexpos, node_size=0, font_size=10)
    nx.draw_networkx_edges(L, pos=vertexpos, edgelist=edgelist, edge_color = cm(ctr//3*3.0/NUM_COLORS), alpha = 0.5, width = 4 ,node_size= 10)
    plt.show()

# %%
# temp = 0

# # print(vertexdem)

# vertexdeminv = {v: k for k, v in vertexdem.items()}

# vertexdmd={}
# for k,v in vertexdeminv.items():
#     dmd = [float(x) for x in v.replace("[",'').replace("]",'').split()]
#     vertexdmd[k] = dmd[::-1]

# print(vertexdmd)

# for pt in new_points:
# #     print(pt)
#     if pt in vertexdmd.values():
#         print(pt)
# print(temp)

# %%
a = [el for el in range(5)]
b = [el for el in range(4,10,2)]
c = [el for el in range(5,12,3)]
d = [b,c]
print(a,d)
# print(el for el in b)
if any(set(a)  for x in d):
    print('a')
# Out:
# [0, 1, 2, 3, 4] [[4, 6, 8], [5, 8, 11]]
# a

# %%
from copy import deepcopy
import networkx as nx
import random
# from scipy.spatial import KDTree
# F = G.copy()
# # print(F)
# for ver in points:
#     F.add_node(tuple(ver))
# print(F)
# # pts = KDTree(F.nodes())
F = nx.complete_graph(10)
H = deepcopy(F)
# nx.draw(F)
path_list = []
for arc in F.edges():
    if random.random() > 0.33:
        H.remove_edge(*arc)
nx.draw(H, with_labels = True)
path_list = []
visited = []
for ver in H.nodes():
    path = []
    visited.append(ver)
    path.append(ver)
    for nb in H.neighbors(ver):
        if nb not in visited and len(path) <= 4:
            path.append(nb)
    if len(path) > 2:
        path_list.append(path)

print(path_list)
# Out:
# [[0, 1, 2], [1, 4, 6], [2, 4, 5, 6], [3, 5, 6, 8], [4, 5, 6, 7, 8], [7, 8, 9]]

# %%
# nx.draw(H, with_labels = True)
ejs = []
for ver in H.nodes():
    for nb in H.neighbors(ver):
        if not((ver, nb) in ejs or (nb, ver) in ejs):
            temp = random.choice([(nb, ver),(ver, nb)])
            ejs.append(temp)
# print(ejs)
K = nx.DiGraph()
K.add_edges_from(ejs)
nx.draw(K, with_labels = True)

# %%
from itertools import combinations
path_list = []

for n1, n2 in combinations(K.nodes(), 2):
    if nx.has_path(K, n1, n2):
        temp = nx.shortest_path(K, n1, n2)
        if len(temp) > 3:
            path_list.append(temp)

removed = []
for i in range(len(path_list)):
    for j in range(i+1,len(path_list)):
        temp_1 = None
        temp_2 = None
        if len(path_list[i]) >= len(path_list[j]):
            temp_1 = path_list[i]
            temp_2 = path_list[j]
        else:
            temp_1 = path_list[j]
            temp_2 = path_list[i]
        if len(set(temp_1).intersection(set(temp_2))) >= 0.8*len(temp_2):
            if temp_2 not in removed:
                removed.append(temp_2)

for path in removed:
    path_list.remove(path)
print(path_list)
# Out:
# [[0, 1, 6, 8, 3, 5], [0, 2, 4, 9], [1, 6, 8, 4, 9], [2, 4, 9, 7], [5, 4, 9, 7], [3, 6, 8, 7], [3, 5, 4, 9]]

# %%
from matplotlib import pyplot as plt
# def get_cmap(n, name='hsv'):
#     return plt.cm.get_cmap(name, n)

P = nx.Graph()
edges = []
for path in path_list:
    path_edges = [(path[n], path[n+1]) for n in range(len(path)-1)]
    P.add_nodes_from(path)
    P.add_edges_from(path_edges)
    edges.append(path_edges)

pos = nx.spring_layout(P)

cm = plt.get_cmap('gist_rainbow')
NUM_COLORS = len(edges)

# colors = [i for i in range(len(path_list))]
linewidths = [2*i for i in range(len(path_list))]
print(len(path_list))

# for i in len(edges):
#     cm(ctr//3*3.0/NUM_COLORS)
    
for ctr, edgelist in enumerate(edges):
#     plt.figure()
    nx.draw_networkx_nodes(P,pos=pos)
    nx.draw_networkx_labels(P,pos=pos)
    nx.draw_networkx_edges(P, pos=pos, edgelist=edgelist, edge_color = cm(ctr/NUM_COLORS), width = 5)
    plt.show()
# plt.savefig('this.png')
# Out:
# 7

# %%
edge_id = {}
ctr = 1
for path in edges:
    for ej in path:
        if ej not in edge_id.keys():
            edge_id[ej] = ctr
            ctr += 1

print(edges)

for ctr, edgelist in enumerate(edges):
#     plt.figure()
    nx.draw_networkx_nodes(P,pos=pos)
    nx.draw_networkx_labels(P,pos=pos)
    nx.draw_networkx_edges(P, pos=pos, edgelist=edgelist, edge_color = cm(ctr//3*3.0/NUM_COLORS), width = 2)
plt.show()
# Out:
# [[(9, 0), (0, 5), (5, 8), (8, 4), (4, 6), (6, 1), (1, 7)], [(2, 9), (9, 0), (0, 5), (5, 8), (8, 4), (4, 6), (6, 3)]]

# %%
import numpy as np
import matplotlib.pyplot as plt


cmaps = [('Perceptually Uniform Sequential', [
            'viridis', 'plasma', 'inferno', 'magma', 'cividis']),
         ('Sequential', [
            'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
            'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
            'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']),
         ('Sequential (2)', [
            'binary', 'gist_yarg', 'gist_gray', 'gray', 'bone', 'pink',
            'spring', 'summer', 'autumn', 'winter', 'cool', 'Wistia',
            'hot', 'afmhot', 'gist_heat', 'copper']),
         ('Diverging', [
            'PiYG', 'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu',
            'RdYlBu', 'RdYlGn', 'Spectral', 'coolwarm', 'bwr', 'seismic']),
         ('Cyclic', ['twilight', 'twilight_shifted', 'hsv']),
         ('Qualitative', [
            'Pastel1', 'Pastel2', 'Paired', 'Accent',
            'Dark2', 'Set1', 'Set2', 'Set3',
            'tab10', 'tab20', 'tab20b', 'tab20c']),
         ('Miscellaneous', [
            'flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern',
            'gnuplot', 'gnuplot2', 'CMRmap', 'cubehelix', 'brg',
            'gist_rainbow', 'rainbow', 'jet', 'turbo', 'nipy_spectral',
            'gist_ncar'])]


gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))


def plot_color_gradients(cmap_category, cmap_list):
    # Create figure and adjust figure height to number of colormaps
    nrows = len(cmap_list)
    figh = 0.35 + 0.15 + (nrows + (nrows-1)*0.1)*0.22
    fig, axs = plt.subplots(nrows=nrows, figsize=(6.4, figh))
    fig.subplots_adjust(top=1-.35/figh, bottom=.15/figh, left=0.2, right=0.99)

    axs[0].set_title(cmap_category + ' colormaps', fontsize=14)

    for ax, cmap_name in zip(axs, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=cmap_name)
        ax.text(-.01, .5, cmap_name, va='center', ha='right', fontsize=10,
                transform=ax.transAxes)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axs:
        ax.set_axis_off()


for cmap_category, cmap_list in cmaps:
    plot_color_gradients(cmap_category, cmap_list)

plt.show()

# %%
with open('./line_concepts/test_lc.txt', 'w') as f:
    f.write('# line-id; edge-order; edge-id; frequency')
#     f.write('\n')
    for i in range(len(edges)):
#         p = path[i]
        for j in range(len(edges[i])):
#             print(edge_id[edges[i][j]])
            f.write('\n')
            f.write(str(i)+ ';' + str(j) + ';' + str(edge_id[edges[i][j]]) + ';' + '0')

# %%
with open

# %%
# '''
# TESTING FOR 9-12
# All bus lines have period 2
# Assign distance/time based on path length
# '''
# from itertools import combinations
# from copy import deepcopy

# lines = {'l1' :(1, 2, 9, 0.5, 2, (1.0, 1.0)), 'l2': (2, 1, 9.25, 0.5, 2, (2.0, 2.0)), 'l3': (3, 4, 9.4, 1, 1, (2.0, 2.1)), 'l4': (4, 3, 9.9, 1, 1, (2.0, 1.1))}

# change_time = {(2,3) : 0.3, (3,2) : 0.3, (3,1): 0.6, (1,3) : 0.6, (1,4): 0.4, (4,1): 0.4, (2,4) : 1.1, (4,2) : 1.1}

# '''
# 9-10
# ''' 

# def count_trips(start, end, line_pool = {}):
#     num_trips = 0
#     for line in line_pool.keys():
#         if start <= line_pool[line][2]:
#             earliest = line_pool[line][2]
#         else:
#             earliest = line_pool[line][2] + ceil((start - line_pool[line][2]) * line+pool[line][4])/line_pool[line][4]
#         num_trips += (end - earliest) // line_pool[line][3]
#     return int(num_trips)

# def possible_trip(start, end, line_pool = {}):
#     lines = deepcopy(line_pool)
#     trips = []
#     rem = count_trips(start, end, lines)
#     while rem > 0:
#         for line in lines.keys():
#             if start <= lines[line][2] and end >= lines[line][2] + lines[line][3]:
#                 trips.append((line, lines[line][2], lines[line][2] + lines[line][3]))
#                 lines[line] = (lines[line][0], lines[line][1], lines[line][2] + 1/lines[line][4], lines[line][3], lines[line][4])
#                 rem -= 1
#     print(trips)
#     return trips

# def next_stop(line_pool, trips, buses, cov):
#     lines = deepcopy(line_pool)
#     rem_trips = []
#     for bus in buses.keys():
#         if trips == []:
#             for i in range(len(buses)):
#                 if buses[i+1] == []:
#                     del buses[i+1]
#             return (buses, cov)
#             break
#         if buses[bus] == []:
#             buses[bus] = [trips[0]]
#             curr_stop = lines[trips[0][0]][1]
#             trips.pop(0)
#             cov += 1

#         for t in trips:
#             curr_time = buses[bus][-1][2]
#             curr_stop = lines[buses[bus][-1][0]][1]
#             if curr_time <= t[1]:
#                 if curr_stop == lines[t[0]][0]:
#                     buses[bus].append(t)
#                     rem_trips.append(t)
#                     cov += 1
#         for t in rem_trips:
#             if t in trips:
#                 trips.remove(t)

#     return (buses, cov)


# temp = deepcopy(lines)
# del temp['l3']
# del temp['l4']

# num = count_trips(9, 11, temp)
# print('num trips', num)
# trips = possible_trip(9, 11, temp)

# buses = {}
# ctr = 0
# rem_trips = len(trips)
# print(rem_trips)

# for i in range(rem_trips):
#     buses[i+1] = []

# while ctr < rem_trips:
#     if buses[1] == []:
#         buses[ctr+1] = [trips[0]]
#         curr_stop = lines[trips[0][0]][1]
#         trips.pop(0)
#         ctr += 1
#     else:
#         buses, ctr = next_stop(lines, trips, buses, ctr)
            
# print(buses)
# Out:
# num trips 7
# [('l1', 9, 9.5), ('l2', 9.25, 9.75), ('l1', 9.5, 10.0), ('l2', 9.75, 10.25), ('l1', 10.0, 10.5), ('l2', 10.25, 10.75), ('l1', 10.5, 11.0)]
# 7
# {1: [('l1', 9, 9.5), ('l2', 9.75, 10.25), ('l1', 10.5, 11.0)], 2: [('l2', 9.25, 9.75), ('l1', 10.0, 10.5)], 3: [('l1', 9.5, 10.0), ('l2', 10.25, 10.75)]}

# %%
import math
from itertools import combinations
from copy import deepcopy
import matplotlib.pyplot as plt

'''
TESTING FOR 9-11
Assign distance/time based on path length
'''

lines = {'l1' :(1, 2, 9, 0.5, 2, (1.0, 1.0), 1.4), 'l2': (2, 1, 9.25, 0.5, 2, (2.0, 2.0), 1.4), 'l3': (3, 4, 9.4, 1, 1, (2.2, 2.0), 1.0), 'l4': (4, 3, 9.9, 1, 1, (2.2, 1.0), 1.0)}

'''
9-11
''' 

def count_trips(start, end, line_pool = {}):
    num_trips = 0
    for line in line_pool.keys():
        if start <= line_pool[line][2]:
            earliest = line_pool[line][2]
        else:
            earliest = line_pool[line][2] + ceil((start - line_pool[line][2]) * line+pool[line][4])/line_pool[line][4]
        num_trips += (end - earliest) // line_pool[line][3]
    return int(num_trips)

def possible_trip(start, end, line_pool = {}):
    lines = deepcopy(line_pool)
    trips = []
    rem = count_trips(start, end, lines)
    while rem > 0:
        for line in lines.keys():
            if start <= lines[line][2] and end >= lines[line][2] + lines[line][3]:
                trips.append([line, lines[line][2], lines[line][2] + lines[line][3], lines[line][6]])
                lines[line] = (lines[line][0], lines[line][1], lines[line][2] + 1/lines[line][4], lines[line][3], lines[line][4], lines[line][5], lines[line][6])
                rem -= 1
    return trips

'''
OPTIMIZATION
'''
def station_dist(line_pool = {}):
    dists = {}
    stations = []
    for line in line_pool.values():
        if line[2] not in stations:
            stations.append((line[1], line[5]))

    for s1, s2 in combinations(stations, 2):
        if s1[0] not in dists.keys():
            dists[s1[0]] = [(s2[0], round(math.sqrt((s1[1][0] - s2[1][0]) ** 2.0 + (s1[1][1] - s2[1][1]) ** 2.0) / 10, 2))]
        else:
            dists[s1[0]].append((s2[0], round(math.sqrt((s1[1][0] - s2[1][0]) ** 2.0 + (s1[1][1] - s2[1][1]) ** 2.0) / 10, 2)))
        if s2[0] not in dists.keys():
            dists[s2[0]] = [(s1[0], round(math.sqrt((s1[1][0] - s2[1][0]) ** 2.0 + (s1[1][1] - s2[1][1]) ** 2.0) / 10, 2))]
        else:
            dists[s2[0]].append((s1[0], round(math.sqrt((s1[1][0] - s2[1][0]) ** 2.0 + (s1[1][1] - s2[1][1]) ** 2.0) / 10, 2)))

    return dists

'''
instead of pairs, try indexing by just stop node

current code
    dists = {}
    stations = []
    for line in line_pool.values():
        if line[2] not in stations:
            stations.append((line[1], line[5]))
    print(stations)
    for s1, s2 in combinations(stations, 2):
        if (s1[0],s2[0]) not in dists.keys():
            dists[(s1[0], s2[0])] = math.sqrt((s1[1][0] - s2[1][0]) ** 2.0 + (s1[1][1] - s2[1][1]) ** 2.0) / 10

    return dists

'''

def possible_swap(end_st, stop_dist):
#     print(stop_dist[end_st])
    next_st = stop_dist[end_st]
    next_st.sort(key = lambda tup: tup[1])
#     print(temp)
#     next_st = [node[0] for node in temp]
# #     print(next_st)
    return next_st

'''
Delete nodes in next_st that belong to the same line
'''

def new_stop(line_pool, trips, buses, cov):
    lines = deepcopy(line_pool)
    rem_trips = []
    for bus in buses.keys():
        if trips == []:
            for i in range(len(buses)):
                if buses[i+1] == []:
                    del buses[i+1]
            return (buses, cov)
            break
        if buses[bus] == []:
            buses[bus] = [trips[0]]
            print(bus, trips[0])
            curr_stop = lines[trips[0][0]][1]
            trips.pop(0)
            cov += 1
        trav = buses[bus][-1][-1]
        for t in trips:
            curr_time = buses[bus][-1][2]
            curr_stop = lines[buses[bus][-1][0]][1]
            for st in possible_swap(curr_stop, stop_dist):
                if st[1] <= t[1] - curr_time:
                    if curr_stop == lines[t[0]][0]:
                        rem_trips.append(t)
#                         trav = buses[bus][-1][-1]
                        t[-1] = round(t[-1]+trav,2)
                        buses[bus].append(t)
                        cov += 1
                        break
        for t in rem_trips:
            if t in trips:
                trips.remove(t)

    return (buses, cov)

def eval(schedule):
    print('Schedule stats: ')
    print('Number of buses: ', len(buses.keys()))
#     print('Distance travelled: ', )
    print('-'*100)

temp = deepcopy(lines)
del temp['l3']
del temp['l4']

print('Lines in use: ', temp)
print('-'*100)

trips = possible_trip(9, 12, temp)
print('Trips: ', trips)
print('-'*100)

rem_trips = count_trips(9, 12, temp)
print('Number of trips: ', rem_trips)
print('-'*100)

print('Pairwise station switch times: ')
stop_dist = station_dist(temp)
for d in stop_dist.items():
    print(d)
next_st = possible_swap(1, stop_dist)
print('-'*100)

buses = {}
ctr = 0

for i in range(rem_trips):
    buses[i+1] = []

while ctr < rem_trips:
    if buses[1] == []:
        buses[ctr+1] = [trips[0]]
#         curr_stop = lines[trips[0][0]][1]
        trips.pop(0)
        ctr += 1
    else:
        buses, ctr = new_stop(lines, trips, buses, ctr)

print('Bus schedule: ')
for bus in buses.items():
    print(bus)
print('-'*100)

stop_coor_x = [2.25]
stop_coor_y = [2.25]

print('Line length: ')
for l in lines.keys():
    stop_coor_x.append(lines[l][5][0])
    stop_coor_y.append(lines[l][5][1])
    print(l, lines[l][6])


plt.figure(figsize=(2,2))
plt.scatter(stop_coor_x, stop_coor_y, c='#000000', alpha = 1.0)

eval(buses)
bus_schedule = deepcopy(buses)
depot_node = (2.25, 2.25)
# def new_schedule(bus_sch):
# Out:
# Lines in use:  {'l1': (1, 2, 9, 0.5, 2, (1.0, 1.0), 1.4), 'l2': (2, 1, 9.25, 0.5, 2, (2.0, 2.0), 1.4)}
# ----------------------------------------------------------------------------------------------------
# Trips:  [['l1', 9, 9.5, 1.4], ['l2', 9.25, 9.75, 1.4], ['l1', 9.5, 10.0, 1.4], ['l2', 9.75, 10.25, 1.4], ['l1', 10.0, 10.5, 1.4], ['l2', 10.25, 10.75, 1.4], ['l1', 10.5, 11.0, 1.4], ['l2', 10.75, 11.25, 1.4], ['l1', 11.0, 11.5, 1.4], ['l2', 11.25, 11.75, 1.4], ['l1', 11.5, 12.0, 1.4]]
# ----------------------------------------------------------------------------------------------------
# Number of trips:  11
# ----------------------------------------------------------------------------------------------------
# Pairwise station switch times:
# (2, [(1, 0.14)])
# (1, [(2, 0.14)])
# ----------------------------------------------------------------------------------------------------
# 2 ['l2', 9.25, 9.75, 1.4]
# 3 ['l1', 9.5, 10.0, 1.4]
# Bus schedule:
# (1, [['l1', 9, 9.5, 1.4], ['l2', 9.75, 10.25, 2.8], ['l1', 10.5, 11.0, 2.8], ['l2', 11.25, 11.75, 2.8]])
# (2, [['l2', 9.25, 9.75, 1.4], ['l1', 10.0, 10.5, 2.8], ['l2', 10.75, 11.25, 2.8], ['l1', 11.5, 12.0, 2.8]])
# (3, [['l1', 9.5, 10.0, 1.4], ['l2', 10.25, 10.75, 2.8], ['l1', 11.0, 11.5, 2.8]])
# ----------------------------------------------------------------------------------------------------
# Line length:
# l1 1.4
# l2 1.4
# l3 1.0
# l4 1.0
# Schedule stats:
# Number of buses:  3
# ----------------------------------------------------------------------------------------------------

# %%
from copy import deepcopy

def count_trips(start, end, line_pool = {}):
    num_trips = 0
    for line in line_pool.keys():
        if start <= line_pool[line][2]:
            earliest = line_pool[line][2]
        else:
            earliest = line_pool[line][2] + ceil((start - line_pool[line][2]) * line+pool[line][4])/line_pool[line][4]
        num_trips += (end - earliest) // line_pool[line][3]
    return int(num_trips)

def all_trips(start, end, line_pool = {}):
    lines = deepcopy(line_pool)
    trips = []
    rem = count_trips(start, end, lines)
    while rem > 0:
        for line in lines.keys():
            if start <= lines[line][2] and end >= lines[line][2] + lines[line][3]:
                trips.append([line, lines[line][2], lines[line][2] + lines[line][3], lines[line][6]])
                lines[line] = (lines[line][0], lines[line][1], lines[line][2] + 1/lines[line][4], lines[line][3], lines[line][4], lines[line][5], lines[line][6])
                rem -= 1
    return trips

def station_dist(line_pool = {}, depot = None):
    dists = {}
    stations = [depot]
    for line in line_pool.values():
        if line[0] not in stations:
            stations.append([line[0], line[5]])
    for s1, s2 in combinations(stations, 2):
        if s1[0] not in dists.keys():
            dists[s1[0]] = [[s2[0], round(math.sqrt((s1[1][0] - s2[1][0]) ** 2.0 + (s1[1][1] - s2[1][1]) ** 2.0)*2, 2)]]
        else:
            dists[s1[0]].append([s2[0], round(math.sqrt((s1[1][0] - s2[1][0]) ** 2.0 + (s1[1][1] - s2[1][1]) ** 2.0)*2, 2)])
        if s2[0] not in dists.keys():
            dists[s2[0]] = [[s1[0], round(math.sqrt((s1[1][0] - s2[1][0]) ** 2.0 + (s1[1][1] - s2[1][1]) ** 2.0)*2, 2)]]
        else:
            dists[s2[0]].append([s1[0], round(math.sqrt((s1[1][0] - s2[1][0]) ** 2.0 + (s1[1][1] - s2[1][1]) ** 2.0)*2, 2)])
    
    for node in dists.keys():
        dists[node].append([node, 0.05])
    return dists

def possible_swap(end_st, stop_dist):
    next_st = stop_dist[end_st]
    next_st.sort(key = lambda tup: tup[1])
    return next_st

'''

'''

def new_stop(line_pool, trips, buses, cov):
    lines = deepcopy(line_pool)
    rem_trips = []
    for bus in buses.keys():
        if trips == []:
            for i in range(len(buses)):
                if buses[i+1] == []:
                    del buses[i+1]
            return (buses, cov)
            break
        if buses[bus] == []:
            buses[bus] = [trips[0]]
            curr_stop = lines[trips[0][0]][1]
            trips.pop(0)
            cov += 1
        
        trav = buses[bus][-1][-1]
        for t in trips:
            curr_time = buses[bus][-1][2]
            curr_stop = lines[buses[bus][-1][0]][1]
            for st in possible_swap(curr_stop, stop_dist):
#                 print(curr_time, t[1], st[1])
                if st[1] <= t[1] - curr_time:
#                     print(buses[bus][-1], t, st[1], curr_time)
                    if curr_stop == lines[t[0]][0]:
                        rem_trips.append(t)
                        t[-1] = round(t[-1]+trav,2)
                        buses[bus].append(t)
                        cov += 1
                        break
        for t in rem_trips:
            if t in trips:
                trips.remove(t)

    return (buses, cov)


def eval(schedule):
    print('Schedule stats: ')
    print('Number of buses: ', len(buses.keys()))
#     print('Distance travelled: ', )
    print('-'*100)

lines = {'l1' :(1, 2, 9, 0.5, 2, (1.0, 1.0), 1.4), 'l2': (2, 1, 9.25, 0.5, 2, (2.0, 2.0), 1.4), 'l3': (3, 4, 9.4, 1, 1, (2.2, 2.0), 1.0), 'l4': (4, 3, 9.9, 1, 1, (2.2, 1.0), 1.0)}

depot_node = [0,(2.25, 2.25)]

temp = deepcopy(lines)
del temp['l3']
del temp['l4']

stop_dist = station_dist(temp, depot_node)
for s in stop_dist.items():
    print(s)
print('-'*100)

b_range = 3.5


trips = all_trips(9, 12, temp)
print('Trips: ', trips)
print('-'*100)

rem_trips = count_trips(9, 12, temp)
print('Number of trips: ', rem_trips)
print('-'*100)

next_st = possible_swap(1, stop_dist)
# print('-'*100)

buses = {}
ctr = 0

for i in range(rem_trips):
    buses[i+1] = []

while ctr < rem_trips:
    if buses[1] == []:
        buses[ctr+1] = [trips[0]]
        buses[ctr+1][-1][-1] = b_range - trips[0][-1]
        trips.pop(0)
        ctr += 1
    else:
        buses, ctr = new_stop(lines, trips, buses, ctr)

#     if ctr > 2:
#         break

print('Bus schedule: ')
for bus in buses.items():
    print(bus)
print('-'*100)
# dh_trips = deadhead_trips(stop_dist)
# def deadhead(bus, line_pool, stat_dists):
#     print(bus[-1])
#     end_st = line_pool[bus[-1][0]][1]
#     print(end_st)
# print('Deadhead trip: ')
# deadhead(buses[1], temp, stop_dist)
# Out:
# (0, [[1, 3.54], [2, 0.71], [0, 0.05]])
# (1, [[0, 3.54], [2, 2.83], [1, 0.05]])
# (2, [[0, 0.71], [1, 2.83], [2, 0.05]])
# ----------------------------------------------------------------------------------------------------
# Trips:  [['l1', 9, 9.5, 1.4], ['l2', 9.25, 9.75, 1.4], ['l1', 9.5, 10.0, 1.4], ['l2', 9.75, 10.25, 1.4], ['l1', 10.0, 10.5, 1.4], ['l2', 10.25, 10.75, 1.4], ['l1', 10.5, 11.0, 1.4], ['l2', 10.75, 11.25, 1.4], ['l1', 11.0, 11.5, 1.4], ['l2', 11.25, 11.75, 1.4], ['l1', 11.5, 12.0, 1.4]]
# ----------------------------------------------------------------------------------------------------
# Number of trips:  11
# ----------------------------------------------------------------------------------------------------
# Bus schedule:
# (1, [['l1', 9, 9.5, 2.1], ['l2', 9.75, 10.25, 3.5], ['l1', 10.5, 11.0, 3.5], ['l2', 11.25, 11.75, 3.5]])
# (2, [['l2', 9.25, 9.75, 1.4], ['l1', 10.0, 10.5, 2.8], ['l2', 10.75, 11.25, 2.8], ['l1', 11.5, 12.0, 2.8]])
# (3, [['l1', 9.5, 10.0, 1.4], ['l2', 10.25, 10.75, 2.8], ['l1', 11.0, 11.5, 2.8]])
# ----------------------------------------------------------------------------------------------------

# %%
import networkx as nx

lines = {'l1' :(1, 2, 9, 0.5, 2, (1.0, 1.0), 1.4), 'l2': (2, 1, 9.25, 0.5, 2, (2.0, 2.0), 1.4), 'l3': (3, 4, 9.4, 1, 1, (2.2, 2.0), 1.0), 'l4': (4, 3, 9.9, 1, 1, (2.2, 1.0), 1.0)}
temp = deepcopy(lines)
del temp['l3']
del temp['l4']

tripz = all_trips(9, 11, temp)
# print(tripz)
trip_x = []
trip_y = []
serv_trip = {}
VS = nx.Graph()
deadhead = []
trip_id = {}
ctr= 1
for t in tripz:
    line_id = int(t[0][1])
#     print((line_id, t[1]))
#     trip_x.append(line_id)
#     trip_y.append(t[1])
    serv_trip[ctr] = (line_id, t[1])
    VS.add_node(ctr, pos = (line_id, t[1]))
    trip_id[str(t)] = ctr
    ctr += 1

print(serv_trip)
deadhead = []

'''
Fix deadhead trips not showing in schedule
Visualise bus schedule
'''

for t in tripz:
    for s in serv_trip.items():
        n1 = serv_trip[trip_id[str(t)]]
        if n1[0] != s[1][0] :
            if t[2] <= s[1][1]:# and n1[0] = s[0]:
                deadhead.append([trip_id[str(t)], s[0]])

VS.add_edges_from(deadhead)
nx.draw(VS, serv_trip, with_labels = True)#)
# Out:
# {1: (1, 9), 2: (2, 9.25), 3: (1, 9.5), 4: (2, 9.75), 5: (1, 10.0), 6: (2, 10.25), 7: (1, 10.5)}

# %%
print(bus_schedule)
print('-'*50)
'''
SCHEDULE VISUALTISATION
'''

print(tripz)
print('-'*50)
# ct = [i for i in range(len(tripz))]
# print(ct)
ctr = 1
pos = {}
edges = []
edge_color = []
Trip_graph = nx.Graph()
for bus in bus_schedule.items():
    for seq in bus[1]:
        pos[ctr] = (seq[1], bus[0])
        ctr += 1
        pos[ctr] = (seq[2], bus[0])
        ctr += 1
        edges.append((ctr-2,ctr-1))
#     print(edges)

# P = nx.Graph()
# edges = []
# for path in path_list:
#     path_edges = [(path[n], path[n+1]) for n in range(len(path)-1)]
#     P.add_nodes_from(path)
#     P.add_edges_from(path_edges)
#     edges.append(path_edges)        

Trip_graph.add_nodes_from(pos)
Trip_graph.add_edges_from(edges)
nx.draw(Trip_graph, pos, with_labels = True)
# Out:
# {1: [['l1', 9, 9.5, 1.4], ['l2', 9.75, 10.25, 2.8], ['l1', 10.5, 11.0, 4.2]], 2: [['l2', 9.25, 9.75, 1.4], ['l1', 10.0, 10.5, 2.8]], 3: [['l1', 9.5, 10.0, 1.4], ['l2', 10.25, 10.75, 2.8]]}
# --------------------------------------------------
# [['l1', 9, 9.5, 1.4], ['l2', 9.25, 9.75, 1.4], ['l4', 9.9, 10.9, 1.0], ['l1', 9.5, 10.0, 1.4], ['l2', 9.75, 10.25, 1.4], ['l1', 10.0, 10.5, 1.4], ['l2', 10.25, 10.75, 1.4], ['l1', 10.5, 11.0, 1.4]]
# --------------------------------------------------

# %% [raw]
# import cv2
# import numpy as np
#
#
# # Reading an image in default mode
# Img = np.zeros((200, 200), np.uint8)
# radius = random.randint(25, 75)
# center_coordinates = [random.randint(0+radius, 100), random.randint(0+radius, 100)]
# # center_coordinates.append([random.randint(100, 200), random.randint(0, 100)])
# # center_coordinates.append([random.randint(0, 100), random.randint(100, 200)])
# # center_coordinates.append([random.randint(100, 200), random.randint(100, 200)])
#
# # Radius of circle
# # radius.append(random.randint(25, 50))
# # radius.append(random.randint(25, 50))
# # radius.append(random.randint(25, 50))
# # radius.append(random.randint(25, 50))
#
# # # Red color in BGR
# color = 255
#
# # Line thickness of -1 px
# thickness = -1
#
# # Using cv2.circle() method
# # Draw a circle of red color of thickness -1 px
# image = cv2.circle(Img, center_coordinates, radius, color, thickness)
# # image = cv2.circle(Img, center_coordinates[1], radius[1], color, thickness)
# # image = cv2.circle(Img, center_coordinates[2], radius[2], color, thickness)
# # image = cv2.circle(Img, center_coordinates[3], radius[3], color, thickness)
#
# # Displaying the image
# plt.imshow(image, cmap='Greys')
# plt.show()

# %%
# temp = 0
visited_nbrs = []
path_list = []
# x_co = []
# y_co = []
for node in vertexLayertInstance.verticesOrigin:
    dummy = None
#     print(node.position)
#     x_co.append(node.position[1])
#     y_co.append(node.position[0])
    nbr_queue = []
    path = [node]
    nbr_queue.append(node)
    for i in range(20):
        max_dem = 0
        max_node = None
        new_node = nbr_queue.pop()
#         print(new_node)
#         print(new_node.position, 'or')#, visited_nbrs)
        for nbr in new_node.goesTo:
#             print(nbr)
            nb = nbr[0]
#             print(nb.position, 'nbr')
            if nb and nb.position.tolist() not in visited_nbrs:
                if nb.dem > max_dem:
                    max_dem = nb.dem
                    max_node = nb
                visited_nbrs.append(nb.position.tolist())
                dummy = nb
#             print(visited_nbrs)
#         print(visited_nbrs[-1])
        if max_node is not None:
            nbr_queue.append(max_node)
#             print(max_node)#.position.tolist())
            path.append(max_node)#.position.tolist())
#             print(nbr_queue)
        else:
            nbr_queue.append(new_node)
            break
        path_list.append(path)

    print(nbr_queue)
#     print(dummy.comesFrom)
    for i in range(20):
        max_dem = 0
        max_node = None
        new_node = nbr_queue.pop()
        for nbr in new_node.comesFrom:
            print(nbr)
#             nbr = nb[0]
            if nbr:
                nb = nbr[0]
                print(nb.position)
                if nb.position.tolist() not in visited_nbrs:
    #                 print(nbr)
    #                 print(nb.position)
                    if nb.dem > max_dem:
                        max_dem = nb.dem
                        max_node = nb
                    visited_nbrs.append(nb.position.tolist())
#                     print(visited_nbrs) 
        if max_node is not None:
            nbr_queue.append(max_node)
#             print(max_node)#.position.tolist())
            path.append(max_node)#.position.tolist())
#             print(nbr_queue)
        else:
            print('a')
            break
        path_list.append(path)
    break
# plt.plot(x_co, y_co, marker = "o")
# print(path_list)
fig, ax = plt.subplots(1,1)
# print(path_list)
for path in path_list:
    x_coor = []
    y_coor = []
#     print(path)
    for ver in path:
#         print(ver)
        x_coor.append(ver.position[1])
        y_coor.append(ver.position[0])
#     print(x_coor, y_coor)
#     plt.xlim(20, 80)
#     plt.ylim(20, 80)
        ax.plot(x_coor, y_coor, marker = "o")
# plt.show()
# fig.show()
plt.savefig(IMAGE_OUTPUT_PATH+'paths.png')
# Out:
# [<vertex.VertexDescendant object at 0x0000024468C426A0>]
# [<vertex.VertexDescendant object at 0x00000244688EA490>, -1.0]
# [25.40251437  9.74032747]
# a

# %%
# path_list = []
# ctr = 0
# visited_nbrs = []
# for node in vertexLayertInstance.verticesOrigin:
#     if node not in visited_nbrs:
#         visited_nbrs.append(node)
#         nbrs = []
#         path = [node]
#         nbrs.append(node)
#         path_stops = 0
# #         while path_stops <= 5 and len(path) <= 50:
#         for i in range(19):
#     #         max_dem = 0
#             sorted_dem = []
#             new_node = visited_nbrs[-1]
#             if new_node.goesTo:
#                 nbrs = [i[0] for i in new_node.goesTo]
#     #         print(nbrs)
#             if any(new_node.comesFrom):
#                 nbrs.extend([i[0] for i in new_node.comesFrom])
#     #         print(nbrs)
#     #         max_dem = max([ver.dem for ver in nbr_queue])
#             sorted_dem = sorted(nbrs, key=lambda y: y.dem)   
#     #         print(sorted_dem)
#             ind = len(sorted_dem)-1
#             added = False
#             while not added and ind >= 0:
#                 if sorted_dem[ind] not in visited_nbrs:
#                     path.append(sorted_dem[ind])
#                     if sorted_dem[ind] in vertexLayertInstance.verticesOrigin:
#                         path_stops += 1
#                     visited_nbrs.append(sorted_dem[ind])
#                     added = True
#                 else:
#                     ind -=1
#     #         print(len(visited_nbrs))

#             print(path_stops)
#         path_list.append(path)
#         if ctr > 5:
#             break
#         else:
#             ctr += 1

# for path in path_list:
#     x_coor = []
#     y_coor = []
# #     print(path)
#     for ver in path:
# #         print(ver)
#         x_coor.append(ver.position[1])
#         y_coor.append(ver.position[0])
#     print(x_coor, y_coor)
# #     plt.xlim(20, 80)
# #     plt.ylim(20, 80)
#     plt.plot(x_coor, y_coor, marker = "o")
#     plt.show()
# # fig.show()
# plt.savefig(IMAGE_OUTPUT_PATH+'paths1.png')

# %%
path_list= []
# temp = random.sample(points, 8)
temp = random.sample(points, 16)
random.shuffle(temp)
starts = temp[:len(temp)//2]
ends = temp[len(temp)//2:]
# for s in starts:

# plt.show()

# %%
graph={}
for vert in vertexLayertInstance.verticesAll:
    print(vert.position)
    for nbr in vert.comesFrom:
        print(nbr[0].position,nbr[0].getDistance(vert))
    for nbr in vert.goesTo:
        print(nbr[0].position,nbr[0].getDistance(vert))
    break
# Out:
# [165.89991852 140.46551588]
# [166.92289086 145.12271616] 4.768226805051947
# [165.33549513 135.06778134] 5.427164259835091

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import math
import random
import bisect
import copy
from scipy.spatial import Voronoi, voronoi_plot_2d
from itertools import accumulate

from randomScatter import RandomScatter
from direction import Direction
from vertex import VertexBase, VertexOrigin, VertexLayer


if __name__ =="__main__":

    ERROR_MESSAGE = '----------------------'
    IMAGE_INPUT_PATH = './image_input/scatter_rate.jpg'
    IMAGE_OUTPUT_PATH = './image_output/'
    ROADMAP_RECTANGLE = ['./image_input/roadMapRectangle_00.jpg']
    ROADMAP_CIRCLE = ['./image_input/roadMapCircle_00.jpg',
                        './image_input/roadMapCircle_01.jpg',
                        './image_input/roadMapCircle_02.jpg',
                        './image_input/roadMapCircle_03.jpg']

    if not os.path.exists(IMAGE_OUTPUT_PATH):
        os.mkdir(IMAGE_OUTPUT_PATH)

    randomScatterInstance = RandomScatter(IMAGE_INPUT_PATH, 200, 0, reverse=True, squared=True)
    randomScatterInstance.readImage()
    randomScatterInstance.randomDots()
    randomScatterInstance.makePoints()

    #run improvePoints twice to refine points' locations
    randomScatterInstance.improvePoints(randomScatterInstance.points)
    randomScatterInstance.improvePoints(randomScatterInstance.improvedPoints) * 1

    directionInstance = Direction(ROADMAP_RECTANGLE, ROADMAP_CIRCLE)

    vertexLayertInstance = VertexLayer(randomScatterInstance, directionInstance)
    
    plt.ion()
    plt.ioff()
    plt.show()
    fig = plt.figure(figsize=(10,10))
    ax = plt.gca()
    ax.set_xlim(left=0, right=randomScatterInstance.shape[1])
    ax.set_ylim(top=0, bottom=randomScatterInstance.shape[0])

    
    for i in range(20):
        vertexLayertInstance.getNextVertices()
        vertexLayertInstance.mergeNextVertices(5)
        vertexLayertInstance.mergeToAll(3)
        vertexLayertInstance.plotLines(vertexLayertInstance.verticesNext, True)
        if len(vertexLayertInstance.verticesNext)<=3:
            break
        vertexLayertInstance.changeNextVertices()

#     print(vertexLayertInstance.verticesAll)   # What do the coordinates mean?

    # vertexLayertInstance.plotLines(vertexLayertInstance.verticesAll+vertexLayertInstance.verticesOrigin)
    # vertexLayertInstance.plotVertices(vertexLayertInstance.verticesOrigin)

    plt.savefig(IMAGE_OUTPUT_PATH+'output.png')
    plt.show()
# Out:
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# [<vertex.VertexDescendant object at 0x0000018708E9F0D0>, -0.0] aaaaaaaaaaaa
# [<vertex.VertexDescendant object at 0x0000018702021820>, -0.0] aaaaaaaaaaaa
# No vertex was added!
# [<vertex.VertexDescendant object at 0x00000187066180D0>, -0.0] aaaaaaaaaaaa
# No vertex was added!
# No vertex was added!
# [<vertex.VertexDescendant object at 0x0000018704646820>, -0.0] aaaaaaaaaaaa

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import math
import random
import bisect
import copy
from scipy.spatial import Voronoi, voronoi_plot_2d
from itertools import accumulate

from randomScatter import RandomScatter
from direction import Direction
from vertex import VertexBase, VertexOrigin, VertexLayer


if __name__ =="__main__":

    ERROR_MESSAGE = '----------------------'
    IMAGE_INPUT_PATH = './image_input/scatter_rate.jpg'
    IMAGE_OUTPUT_PATH = './image_output/'
    ROADMAP_RECTANGLE = ['./image_input/roadMapRectangle_00.jpg']
    ROADMAP_CIRCLE = ['./image_input/roadMapCircle_00.jpg',
                        './image_input/roadMapCircle_01.jpg',
                        './image_input/roadMapCircle_02.jpg',
                        './image_input/roadMapCircle_03.jpg']

    if not os.path.exists(IMAGE_OUTPUT_PATH):
        os.mkdir(IMAGE_OUTPUT_PATH)

    randomScatterInstance = RandomScatter(IMAGE_INPUT_PATH, 200, 0, reverse=True, squared=True)
    randomScatterInstance.readImage()
    randomScatterInstance.randomDots()
    randomScatterInstance.makePoints()

    #run improvePoints twice to refine points' locations
    randomScatterInstance.improvePoints(randomScatterInstance.points)
    randomScatterInstance.improvePoints(randomScatterInstance.improvedPoints) * 1

    directionInstance = Direction(ROADMAP_RECTANGLE, ROADMAP_CIRCLE)

    vertexLayertInstance = VertexLayer(randomScatterInstance, directionInstance)
    
    plt.ion()
    plt.ioff()
    plt.show()
    fig = plt.figure(figsize=(10,10))
    ax = plt.gca()
    ax.set_xlim(left=0, right=randomScatterInstance.shape[1])
    ax.set_ylim(top=0, bottom=randomScatterInstance.shape[0])

    
    for i in range(20):
        vertexLayertInstance.getNextVertices()
        vertexLayertInstance.mergeNextVertices(5)
        vertexLayertInstance.mergeToAll(3)
        vertexLayertInstance.plotLines(vertexLayertInstance.verticesNext, True)
        if len(vertexLayertInstance.verticesNext)<=3:
            break
        vertexLayertInstance.changeNextVertices()

#     print(vertexLayertInstance.verticesAll)   # What do the coordinates mean?

    # vertexLayertInstance.plotLines(vertexLayertInstance.verticesAll+vertexLayertInstance.verticesOrigin)
    # vertexLayertInstance.plotVertices(vertexLayertInstance.verticesOrigin)

    plt.savefig(IMAGE_OUTPUT_PATH+'output.png')
    plt.show()
# Out:
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# No vertex was added!
# [<vertex.VertexDescendant object at 0x000001870616E7C0>, -0.0] aaaaaaaaaaaa
# [<vertex.VertexDescendant object at 0x0000018702203370>, -0.0] aaaaaaaaaaaa
# [<vertex.VertexDescendant object at 0x0000018702203370>, -0.0] aaaaaaaaaaaa
# [<vertex.VertexDescendant object at 0x000001870647A700>, -0.0] aaaaaaaaaaaa
# [<vertex.VertexDescendant object at 0x0000018701E00130>, -0.0] aaaaaaaaaaaa
# No vertex was added!
# No vertex was added!
# [<vertex.VertexDescendant object at 0x000001870647ADC0>, -0.0] aaaaaaaaaaaa
# [<vertex.VertexDescendant object at 0x00000187021D0FD0>, -0.0] aaaaaaaaaaaa
